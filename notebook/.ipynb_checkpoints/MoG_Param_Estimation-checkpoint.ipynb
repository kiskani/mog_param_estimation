# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
def sample_from_mog(n, rho, mu1, mu2, sigma1, sigma2):
    choice_vec = np.random.uniform(0, 1, n) > rho
    Z = np.random.normal(0,1, n)
    normal_vec = sigma1*Z + mu1
    return choice_vec*((sigma2-sigma1)*Z+(mu2-mu1)) + normal_vec

# %%
rho = 0.4 
mu1 = -2
mu2 = 2
sigma1 = 1
sigma2 = 1

W = sample_from_mog(1000000,rho, mu1, mu2, sigma1, sigma2)

y = np.linspace(-5,5)
p = (rho/(sigma1*np.sqrt(2*np.pi)))*np.exp(-(y-mu1)**2/(2*sigma1**2)) + \
    ((1-rho)/(sigma2*np.sqrt(2*np.pi)))*np.exp(-(y-mu2)**2/(2*sigma2**2)) 
lp = np.log(p)

# %%
fig, axs = plt.subplots(2, 1,figsize=(15,10))
axs[0].plot(y, p, linewidth=5)
axs[1].plot(y, lp)
axs[0].grid(axis="x")
axs[1].grid(axis="x")
axs[0].title.set_text(r'Mixture of Gaussians ($\rho = 0.4, \mu_1=-2, \mu_2=2, \sigma_1 = \sigma_2 = 1$)')
axs[1].title.set_text(r'Log of Mixture of Gaussians ($\rho = 0.4, \mu_1=-2, \mu_2=2, \sigma_1 = \sigma_2 = 1$)')
s0 = axs[0].hist(W, bins='auto', density=1)

# %% [markdown]
# # Maximum Likelihood Estimation of the MoG parameters
# Assume that the vector W is sampled from the above MoG and is given to us. We know nothing else other than this vector and the fact that we have a mixture of 2 Gaussians. We want to find the MLE estimate of the 5 parameters above.

# %% [markdown]
# ## Gradient descent estimation

# %%
def compute_grad_wrt_rho(Y, rho, mu1, mu2, sigma1, sigma2):
    num = (1/sigma1)*np.exp(-((Y-mu1)**2)/(2*(sigma1**2))) - (1/sigma2)*np.exp(-((Y-mu2)**2)/(2*sigma2**2))
    denom = ((rho/sigma1)*np.exp(-((Y-mu1)**2)/(2*sigma1**2)) +\
                                  ((1-rho)/sigma2)*np.exp(-((Y-mu2)**2)/(2*sigma2**2)))
    return -np.sum(num/denom)

# %%
def compute_grad_wrt_mu1(Y, rho, mu1, mu2, sigma1, sigma2):
    num = (rho/sigma1)*np.exp(-(Y-mu1)**2/(2*sigma1**2))*((Y-mu1)/(sigma1**2))
    denom = ((rho/sigma1)*np.exp(-(Y-mu1)**2/(2*sigma1**2)) +\
                                  ((1-rho)/sigma2)*np.exp(-(Y-mu2)**2/(2*sigma2**2)))
    return -np.sum(num/denom)

# %%
def compute_grad_wrt_mu2(Y, rho, mu1, mu2, sigma1, sigma2):
    num = ((1-rho)/sigma2)*np.exp(-(Y-mu2)**2/(2*sigma2**2))*((Y-mu2)/(sigma2**2))
    denom = ((rho/sigma1)*np.exp(-(Y-mu1)**2/(2*sigma1**2)) +\
                                  ((1-rho)/sigma2)*np.exp(-(Y-mu2)**2/(2*sigma2**2)))
    return -np.sum(num/denom)

# %%
def compute_grad_wrt_sigma1(Y, rho, mu1, mu2, sigma1, sigma2):
    num = (rho/sigma1**2)*np.exp(-(Y-mu1)**2/(2*sigma1**2))*(((Y-mu1)**2)/(sigma1**2) -1 )
    denom = ((rho/sigma1)*np.exp(-(Y-mu1)**2/(2*sigma1**2)) +\
                                  ((1-rho)/sigma2)*np.exp(-(Y-mu2)**2/(2*sigma2**2)))
    return -np.sum(num/denom)

# %%
def compute_grad_wrt_sigma2(Y, rho, mu1, mu2, sigma1, sigma2):
    num = ((1-rho)/sigma2**2)*np.exp(-(Y-mu2)**2/(2*sigma2**2))*(((Y-mu2)**2)/(sigma2**2) - 1)
    denom = ((rho/sigma1)*np.exp(-(Y-mu1)**2/(2*sigma1**2)) +\
                                  ((1-rho)/sigma2)*np.exp(-(Y-mu2)**2/(2*sigma2**2)))
    return -np.sum(num/denom)

# %%
def gradient_descent_update_params(Y, rho, mu1, mu2, sigma1, sigma2, learning_rate):
    rho_update = learning_rate * compute_grad_wrt_rho(Y, rho, mu1, mu2, sigma1, sigma2)
    mu1_update = learning_rate * compute_grad_wrt_mu1(Y, rho, mu1, mu2, sigma1, sigma2)
    mu2_update = learning_rate * compute_grad_wrt_mu2(Y, rho, mu1, mu2, sigma1, sigma2)
    sigma1_update = learning_rate * compute_grad_wrt_sigma1(Y, rho, mu1, mu2, sigma1, sigma2)
    sigma2_update = learning_rate * compute_grad_wrt_sigma2(Y, rho, mu1, mu2, sigma1, sigma2)
    
    rho -= rho_update
    mu1 -= mu1_update
    mu2 -= mu2_update
    sigma1 -= sigma1_update
    sigma2 -= sigma2_update
    #print(rho_update, mu1_update, mu2_update, sigma1_update, sigma2_update)
    return rho, mu1, mu2, sigma1, sigma2

# %%
learning_rate = 0.0000001
rho, mu1, mu2, sigma1, sigma2 = 0.5, 0, 1, 2, 2
for _ in range(1000):
    print('rho=', "%.2f" % rho, '\tmu1=', "%.2f" % mu1, '\tmu2=', "%.2f" % mu2, \
          '\tsigma1=', "%.2f" % sigma1, '\tsigma2=', "%.2f" % sigma2)
    rho, mu1, mu2, sigma1, sigma2 = gradient_descent_update_params(W, rho, mu1, mu2, sigma1, sigma2, learning_rate)
# Out:
# rho= 0.50 	mu1= 0.00 	mu2= 1.00 	sigma1= 2.00 	sigma2= 2.00
# rho= 0.50 	mu1= -0.00 	mu2= 1.00 	sigma1= 2.01 	sigma2= 2.00
# rho= 0.50 	mu1= -0.00 	mu2= 1.00 	sigma1= 2.01 	sigma2= 2.00
# rho= 0.51 	mu1= -0.01 	mu2= 1.00 	sigma1= 2.02 	sigma2= 2.00
# rho= 0.51 	mu1= -0.01 	mu2= 1.00 	sigma1= 2.02 	sigma2= 2.00
# rho= 0.51 	mu1= -0.01 	mu2= 1.00 	sigma1= 2.03 	sigma2= 2.00
# rho= 0.51 	mu1= -0.01 	mu2= 1.00 	sigma1= 2.03 	sigma2= 2.00
# rho= 0.51 	mu1= -0.01 	mu2= 1.00 	sigma1= 2.04 	sigma2= 2.00
# rho= 0.51 	mu1= -0.02 	mu2= 1.00 	sigma1= 2.04 	sigma2= 2.00
# rho= 0.52 	mu1= -0.02 	mu2= 1.00 	sigma1= 2.05 	sigma2= 2.01
# rho= 0.52 	mu1= -0.02 	mu2= 1.00 	sigma1= 2.05 	sigma2= 2.01
# rho= 0.52 	mu1= -0.02 	mu2= 1.00 	sigma1= 2.05 	sigma2= 2.01
# rho= 0.52 	mu1= -0.02 	mu2= 1.00 	sigma1= 2.06 	sigma2= 2.01
# rho= 0.52 	mu1= -0.02 	mu2= 1.00 	sigma1= 2.06 	sigma2= 2.01
# rho= 0.52 	mu1= -0.03 	mu2= 1.00 	sigma1= 2.07 	sigma2= 2.01
# rho= 0.53 	mu1= -0.03 	mu2= 1.00 	sigma1= 2.07 	sigma2= 2.01
# rho= 0.53 	mu1= -0.03 	mu2= 1.00 	sigma1= 2.07 	sigma2= 2.01
# rho= 0.53 	mu1= -0.03 	mu2= 1.00 	sigma1= 2.08 	sigma2= 2.01
# rho= 0.53 	mu1= -0.03 	mu2= 1.00 	sigma1= 2.08 	sigma2= 2.01
# rho= 0.53 	mu1= -0.03 	mu2= 1.00 	sigma1= 2.09 	sigma2= 2.01
# rho= 0.53 	mu1= -0.03 	mu2= 1.00 	sigma1= 2.09 	sigma2= 2.01
# rho= 0.53 	mu1= -0.04 	mu2= 1.00 	sigma1= 2.09 	sigma2= 2.01
# rho= 0.53 	mu1= -0.04 	mu2= 1.00 	sigma1= 2.10 	sigma2= 2.01
# rho= 0.54 	mu1= -0.04 	mu2= 1.00 	sigma1= 2.10 	sigma2= 2.01
# rho= 0.54 	mu1= -0.04 	mu2= 1.00 	sigma1= 2.10 	sigma2= 2.01
# rho= 0.54 	mu1= -0.04 	mu2= 1.00 	sigma1= 2.11 	sigma2= 2.00
# rho= 0.54 	mu1= -0.04 	mu2= 1.00 	sigma1= 2.11 	sigma2= 2.00
# rho= 0.54 	mu1= -0.04 	mu2= 1.00 	sigma1= 2.11 	sigma2= 2.00
# rho= 0.54 	mu1= -0.04 	mu2= 1.00 	sigma1= 2.11 	sigma2= 2.00
# rho= 0.54 	mu1= -0.05 	mu2= 1.00 	sigma1= 2.12 	sigma2= 2.00
# rho= 0.54 	mu1= -0.05 	mu2= 1.00 	sigma1= 2.12 	sigma2= 2.00
# rho= 0.54 	mu1= -0.05 	mu2= 1.00 	sigma1= 2.12 	sigma2= 2.00
# rho= 0.54 	mu1= -0.05 	mu2= 1.01 	sigma1= 2.12 	sigma2= 2.00
# rho= 0.54 	mu1= -0.05 	mu2= 1.01 	sigma1= 2.13 	sigma2= 2.00
# rho= 0.55 	mu1= -0.05 	mu2= 1.01 	sigma1= 2.13 	sigma2= 2.00
# rho= 0.55 	mu1= -0.05 	mu2= 1.01 	sigma1= 2.13 	sigma2= 2.00
# rho= 0.55 	mu1= -0.05 	mu2= 1.01 	sigma1= 2.13 	sigma2= 2.00
# rho= 0.55 	mu1= -0.05 	mu2= 1.01 	sigma1= 2.14 	sigma2= 2.00
# rho= 0.55 	mu1= -0.05 	mu2= 1.01 	sigma1= 2.14 	sigma2= 2.00
# rho= 0.55 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.14 	sigma2= 2.00
# rho= 0.55 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.14 	sigma2= 2.00
# rho= 0.55 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.15 	sigma2= 2.00
# rho= 0.55 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.15 	sigma2= 2.00
# rho= 0.55 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.15 	sigma2= 2.00
# rho= 0.55 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.15 	sigma2= 2.00
# rho= 0.55 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.15 	sigma2= 2.00
# rho= 0.55 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.16 	sigma2= 2.00
# rho= 0.55 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.16 	sigma2= 1.99
# rho= 0.56 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.16 	sigma2= 1.99
# rho= 0.56 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.16 	sigma2= 1.99
# rho= 0.56 	mu1= -0.06 	mu2= 1.01 	sigma1= 2.16 	sigma2= 1.99
# rho= 0.56 	mu1= -0.06 	mu2= 1.02 	sigma1= 2.16 	sigma2= 1.99
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.17 	sigma2= 1.99
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.17 	sigma2= 1.99
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.17 	sigma2= 1.99
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.17 	sigma2= 1.99
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.17 	sigma2= 1.99
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.17 	sigma2= 1.99
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.18 	sigma2= 1.99
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.18 	sigma2= 1.99
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.18 	sigma2= 1.99
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.18 	sigma2= 1.99
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.18 	sigma2= 1.98
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.18 	sigma2= 1.98
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.18 	sigma2= 1.98
# rho= 0.56 	mu1= -0.07 	mu2= 1.02 	sigma1= 2.18 	sigma2= 1.98
# rho= 0.56 	mu1= -0.08 	mu2= 1.02 	sigma1= 2.19 	sigma2= 1.98
# rho= 0.56 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.19 	sigma2= 1.98
# rho= 0.56 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.19 	sigma2= 1.98
# rho= 0.56 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.19 	sigma2= 1.98
# rho= 0.56 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.19 	sigma2= 1.98
# rho= 0.56 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.19 	sigma2= 1.98
# rho= 0.57 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.19 	sigma2= 1.98
# rho= 0.57 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.19 	sigma2= 1.98
# rho= 0.57 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.19 	sigma2= 1.98
# rho= 0.57 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.20 	sigma2= 1.97
# rho= 0.57 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.20 	sigma2= 1.97
# rho= 0.57 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.20 	sigma2= 1.97
# rho= 0.57 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.20 	sigma2= 1.97
# rho= 0.57 	mu1= -0.08 	mu2= 1.03 	sigma1= 2.20 	sigma2= 1.97
# rho= 0.57 	mu1= -0.08 	mu2= 1.04 	sigma1= 2.20 	sigma2= 1.97
# rho= 0.57 	mu1= -0.08 	mu2= 1.04 	sigma1= 2.20 	sigma2= 1.97
# rho= 0.57 	mu1= -0.09 	mu2= 1.04 	sigma1= 2.20 	sigma2= 1.97
# rho= 0.57 	mu1= -0.09 	mu2= 1.04 	sigma1= 2.20 	sigma2= 1.97
# rho= 0.57 	mu1= -0.09 	mu2= 1.04 	sigma1= 2.20 	sigma2= 1.97
# rho= 0.57 	mu1= -0.09 	mu2= 1.04 	sigma1= 2.20 	sigma2= 1.97
# rho= 0.57 	mu1= -0.09 	mu2= 1.04 	sigma1= 2.21 	sigma2= 1.97
# rho= 0.57 	mu1= -0.09 	mu2= 1.04 	sigma1= 2.21 	sigma2= 1.97
# rho= 0.57 	mu1= -0.09 	mu2= 1.04 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.09 	mu2= 1.04 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.09 	mu2= 1.04 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.09 	mu2= 1.04 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.09 	mu2= 1.04 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.09 	mu2= 1.05 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.09 	mu2= 1.05 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.09 	mu2= 1.05 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.09 	mu2= 1.05 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.09 	mu2= 1.05 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.09 	mu2= 1.05 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.10 	mu2= 1.05 	sigma1= 2.21 	sigma2= 1.96
# rho= 0.57 	mu1= -0.10 	mu2= 1.05 	sigma1= 2.21 	sigma2= 1.95
# rho= 0.57 	mu1= -0.10 	mu2= 1.05 	sigma1= 2.22 	sigma2= 1.95
# rho= 0.57 	mu1= -0.10 	mu2= 1.05 	sigma1= 2.22 	sigma2= 1.95
# rho= 0.57 	mu1= -0.10 	mu2= 1.05 	sigma1= 2.22 	sigma2= 1.95
# rho= 0.57 	mu1= -0.10 	mu2= 1.06 	sigma1= 2.22 	sigma2= 1.95
# rho= 0.57 	mu1= -0.10 	mu2= 1.06 	sigma1= 2.22 	sigma2= 1.95
# rho= 0.57 	mu1= -0.10 	mu2= 1.06 	sigma1= 2.22 	sigma2= 1.95
# rho= 0.57 	mu1= -0.10 	mu2= 1.06 	sigma1= 2.22 	sigma2= 1.95
# rho= 0.57 	mu1= -0.10 	mu2= 1.06 	sigma1= 2.22 	sigma2= 1.95
# rho= 0.57 	mu1= -0.10 	mu2= 1.06 	sigma1= 2.22 	sigma2= 1.95
# rho= 0.57 	mu1= -0.10 	mu2= 1.06 	sigma1= 2.22 	sigma2= 1.95
# rho= 0.57 	mu1= -0.10 	mu2= 1.06 	sigma1= 2.22 	sigma2= 1.94
# rho= 0.57 	mu1= -0.10 	mu2= 1.06 	sigma1= 2.22 	sigma2= 1.94
# rho= 0.57 	mu1= -0.10 	mu2= 1.06 	sigma1= 2.22 	sigma2= 1.94
# rho= 0.57 	mu1= -0.10 	mu2= 1.06 	sigma1= 2.22 	sigma2= 1.94
# rho= 0.57 	mu1= -0.10 	mu2= 1.07 	sigma1= 2.22 	sigma2= 1.94
# rho= 0.57 	mu1= -0.10 	mu2= 1.07 	sigma1= 2.22 	sigma2= 1.94
# rho= 0.57 	mu1= -0.11 	mu2= 1.07 	sigma1= 2.22 	sigma2= 1.94
# rho= 0.57 	mu1= -0.11 	mu2= 1.07 	sigma1= 2.22 	sigma2= 1.94
# rho= 0.57 	mu1= -0.11 	mu2= 1.07 	sigma1= 2.22 	sigma2= 1.94
# rho= 0.57 	mu1= -0.11 	mu2= 1.07 	sigma1= 2.22 	sigma2= 1.94
# rho= 0.58 	mu1= -0.11 	mu2= 1.07 	sigma1= 2.22 	sigma2= 1.94
# rho= 0.58 	mu1= -0.11 	mu2= 1.07 	sigma1= 2.23 	sigma2= 1.94
# rho= 0.58 	mu1= -0.11 	mu2= 1.07 	sigma1= 2.23 	sigma2= 1.93
# rho= 0.58 	mu1= -0.11 	mu2= 1.07 	sigma1= 2.23 	sigma2= 1.93
# rho= 0.58 	mu1= -0.11 	mu2= 1.07 	sigma1= 2.23 	sigma2= 1.93
# rho= 0.58 	mu1= -0.11 	mu2= 1.08 	sigma1= 2.23 	sigma2= 1.93
# rho= 0.58 	mu1= -0.11 	mu2= 1.08 	sigma1= 2.23 	sigma2= 1.93
# rho= 0.58 	mu1= -0.11 	mu2= 1.08 	sigma1= 2.23 	sigma2= 1.93
# rho= 0.58 	mu1= -0.11 	mu2= 1.08 	sigma1= 2.23 	sigma2= 1.93
# rho= 0.58 	mu1= -0.11 	mu2= 1.08 	sigma1= 2.23 	sigma2= 1.93
# rho= 0.58 	mu1= -0.11 	mu2= 1.08 	sigma1= 2.23 	sigma2= 1.93
# rho= 0.58 	mu1= -0.11 	mu2= 1.08 	sigma1= 2.23 	sigma2= 1.93
# rho= 0.58 	mu1= -0.11 	mu2= 1.08 	sigma1= 2.23 	sigma2= 1.93
# rho= 0.58 	mu1= -0.12 	mu2= 1.08 	sigma1= 2.23 	sigma2= 1.92
# rho= 0.58 	mu1= -0.12 	mu2= 1.09 	sigma1= 2.23 	sigma2= 1.92
# rho= 0.58 	mu1= -0.12 	mu2= 1.09 	sigma1= 2.23 	sigma2= 1.92
# rho= 0.58 	mu1= -0.12 	mu2= 1.09 	sigma1= 2.23 	sigma2= 1.92
# rho= 0.58 	mu1= -0.12 	mu2= 1.09 	sigma1= 2.23 	sigma2= 1.92
# rho= 0.58 	mu1= -0.12 	mu2= 1.09 	sigma1= 2.23 	sigma2= 1.92
# rho= 0.58 	mu1= -0.12 	mu2= 1.09 	sigma1= 2.23 	sigma2= 1.92
# rho= 0.58 	mu1= -0.12 	mu2= 1.09 	sigma1= 2.23 	sigma2= 1.92
# rho= 0.58 	mu1= -0.12 	mu2= 1.09 	sigma1= 2.23 	sigma2= 1.92
# rho= 0.58 	mu1= -0.12 	mu2= 1.09 	sigma1= 2.23 	sigma2= 1.92
# rho= 0.58 	mu1= -0.12 	mu2= 1.09 	sigma1= 2.23 	sigma2= 1.92
# rho= 0.58 	mu1= -0.12 	mu2= 1.10 	sigma1= 2.23 	sigma2= 1.91
# rho= 0.58 	mu1= -0.12 	mu2= 1.10 	sigma1= 2.23 	sigma2= 1.91
# rho= 0.58 	mu1= -0.12 	mu2= 1.10 	sigma1= 2.23 	sigma2= 1.91
# rho= 0.58 	mu1= -0.12 	mu2= 1.10 	sigma1= 2.23 	sigma2= 1.91
# rho= 0.58 	mu1= -0.12 	mu2= 1.10 	sigma1= 2.23 	sigma2= 1.91
# rho= 0.58 	mu1= -0.12 	mu2= 1.10 	sigma1= 2.23 	sigma2= 1.91
# rho= 0.58 	mu1= -0.13 	mu2= 1.10 	sigma1= 2.23 	sigma2= 1.91
# rho= 0.58 	mu1= -0.13 	mu2= 1.10 	sigma1= 2.23 	sigma2= 1.91
# rho= 0.58 	mu1= -0.13 	mu2= 1.10 	sigma1= 2.23 	sigma2= 1.91
# rho= 0.58 	mu1= -0.13 	mu2= 1.11 	sigma1= 2.23 	sigma2= 1.91
# rho= 0.58 	mu1= -0.13 	mu2= 1.11 	sigma1= 2.23 	sigma2= 1.90
# rho= 0.58 	mu1= -0.13 	mu2= 1.11 	sigma1= 2.23 	sigma2= 1.90
# rho= 0.58 	mu1= -0.13 	mu2= 1.11 	sigma1= 2.23 	sigma2= 1.90
# rho= 0.58 	mu1= -0.13 	mu2= 1.11 	sigma1= 2.23 	sigma2= 1.90
# rho= 0.58 	mu1= -0.13 	mu2= 1.11 	sigma1= 2.23 	sigma2= 1.90
# rho= 0.58 	mu1= -0.13 	mu2= 1.11 	sigma1= 2.23 	sigma2= 1.90
# rho= 0.58 	mu1= -0.13 	mu2= 1.11 	sigma1= 2.23 	sigma2= 1.90
# rho= 0.58 	mu1= -0.13 	mu2= 1.11 	sigma1= 2.24 	sigma2= 1.90
# rho= 0.58 	mu1= -0.13 	mu2= 1.12 	sigma1= 2.24 	sigma2= 1.90
# rho= 0.58 	mu1= -0.13 	mu2= 1.12 	sigma1= 2.24 	sigma2= 1.90
# rho= 0.58 	mu1= -0.13 	mu2= 1.12 	sigma1= 2.24 	sigma2= 1.90
# rho= 0.58 	mu1= -0.13 	mu2= 1.12 	sigma1= 2.24 	sigma2= 1.89
# rho= 0.58 	mu1= -0.14 	mu2= 1.12 	sigma1= 2.24 	sigma2= 1.89
# rho= 0.58 	mu1= -0.14 	mu2= 1.12 	sigma1= 2.24 	sigma2= 1.89
# rho= 0.58 	mu1= -0.14 	mu2= 1.12 	sigma1= 2.24 	sigma2= 1.89
# rho= 0.58 	mu1= -0.14 	mu2= 1.12 	sigma1= 2.24 	sigma2= 1.89
# rho= 0.58 	mu1= -0.14 	mu2= 1.13 	sigma1= 2.24 	sigma2= 1.89
# rho= 0.58 	mu1= -0.14 	mu2= 1.13 	sigma1= 2.24 	sigma2= 1.89
# rho= 0.58 	mu1= -0.14 	mu2= 1.13 	sigma1= 2.24 	sigma2= 1.89
# rho= 0.58 	mu1= -0.14 	mu2= 1.13 	sigma1= 2.24 	sigma2= 1.89
# rho= 0.58 	mu1= -0.14 	mu2= 1.13 	sigma1= 2.24 	sigma2= 1.89
# rho= 0.58 	mu1= -0.14 	mu2= 1.13 	sigma1= 2.24 	sigma2= 1.88
# rho= 0.58 	mu1= -0.14 	mu2= 1.13 	sigma1= 2.24 	sigma2= 1.88
# rho= 0.58 	mu1= -0.14 	mu2= 1.13 	sigma1= 2.24 	sigma2= 1.88
# rho= 0.58 	mu1= -0.14 	mu2= 1.14 	sigma1= 2.24 	sigma2= 1.88
# rho= 0.58 	mu1= -0.14 	mu2= 1.14 	sigma1= 2.24 	sigma2= 1.88
# rho= 0.58 	mu1= -0.14 	mu2= 1.14 	sigma1= 2.24 	sigma2= 1.88
# rho= 0.58 	mu1= -0.14 	mu2= 1.14 	sigma1= 2.24 	sigma2= 1.88
# rho= 0.58 	mu1= -0.15 	mu2= 1.14 	sigma1= 2.24 	sigma2= 1.88
# rho= 0.58 	mu1= -0.15 	mu2= 1.14 	sigma1= 2.24 	sigma2= 1.88
# rho= 0.58 	mu1= -0.15 	mu2= 1.14 	sigma1= 2.24 	sigma2= 1.87
# rho= 0.58 	mu1= -0.15 	mu2= 1.14 	sigma1= 2.24 	sigma2= 1.87
# rho= 0.58 	mu1= -0.15 	mu2= 1.15 	sigma1= 2.24 	sigma2= 1.87
# rho= 0.59 	mu1= -0.15 	mu2= 1.15 	sigma1= 2.24 	sigma2= 1.87
# rho= 0.59 	mu1= -0.15 	mu2= 1.15 	sigma1= 2.24 	sigma2= 1.87
# rho= 0.59 	mu1= -0.15 	mu2= 1.15 	sigma1= 2.24 	sigma2= 1.87
# rho= 0.59 	mu1= -0.15 	mu2= 1.15 	sigma1= 2.24 	sigma2= 1.87
# rho= 0.59 	mu1= -0.15 	mu2= 1.15 	sigma1= 2.24 	sigma2= 1.87
# rho= 0.59 	mu1= -0.15 	mu2= 1.15 	sigma1= 2.24 	sigma2= 1.87
# rho= 0.59 	mu1= -0.15 	mu2= 1.16 	sigma1= 2.24 	sigma2= 1.86
# rho= 0.59 	mu1= -0.15 	mu2= 1.16 	sigma1= 2.24 	sigma2= 1.86
# rho= 0.59 	mu1= -0.15 	mu2= 1.16 	sigma1= 2.24 	sigma2= 1.86
# rho= 0.59 	mu1= -0.16 	mu2= 1.16 	sigma1= 2.24 	sigma2= 1.86
# rho= 0.59 	mu1= -0.16 	mu2= 1.16 	sigma1= 2.24 	sigma2= 1.86
# rho= 0.59 	mu1= -0.16 	mu2= 1.16 	sigma1= 2.24 	sigma2= 1.86
# rho= 0.59 	mu1= -0.16 	mu2= 1.16 	sigma1= 2.24 	sigma2= 1.86
# rho= 0.59 	mu1= -0.16 	mu2= 1.17 	sigma1= 2.24 	sigma2= 1.86
# rho= 0.59 	mu1= -0.16 	mu2= 1.17 	sigma1= 2.24 	sigma2= 1.86
# rho= 0.59 	mu1= -0.16 	mu2= 1.17 	sigma1= 2.24 	sigma2= 1.85
# rho= 0.59 	mu1= -0.16 	mu2= 1.17 	sigma1= 2.24 	sigma2= 1.85
# rho= 0.59 	mu1= -0.16 	mu2= 1.17 	sigma1= 2.24 	sigma2= 1.85
# rho= 0.59 	mu1= -0.16 	mu2= 1.17 	sigma1= 2.24 	sigma2= 1.85
# rho= 0.59 	mu1= -0.16 	mu2= 1.17 	sigma1= 2.24 	sigma2= 1.85
# rho= 0.59 	mu1= -0.16 	mu2= 1.18 	sigma1= 2.24 	sigma2= 1.85
# rho= 0.59 	mu1= -0.16 	mu2= 1.18 	sigma1= 2.24 	sigma2= 1.85
# rho= 0.59 	mu1= -0.16 	mu2= 1.18 	sigma1= 2.24 	sigma2= 1.85
# rho= 0.59 	mu1= -0.17 	mu2= 1.18 	sigma1= 2.24 	sigma2= 1.85
# rho= 0.59 	mu1= -0.17 	mu2= 1.18 	sigma1= 2.24 	sigma2= 1.84
# rho= 0.59 	mu1= -0.17 	mu2= 1.18 	sigma1= 2.24 	sigma2= 1.84
# rho= 0.59 	mu1= -0.17 	mu2= 1.18 	sigma1= 2.24 	sigma2= 1.84
# rho= 0.59 	mu1= -0.17 	mu2= 1.19 	sigma1= 2.24 	sigma2= 1.84
# rho= 0.59 	mu1= -0.17 	mu2= 1.19 	sigma1= 2.24 	sigma2= 1.84
# rho= 0.59 	mu1= -0.17 	mu2= 1.19 	sigma1= 2.24 	sigma2= 1.84
# rho= 0.59 	mu1= -0.17 	mu2= 1.19 	sigma1= 2.24 	sigma2= 1.84
# rho= 0.59 	mu1= -0.17 	mu2= 1.19 	sigma1= 2.24 	sigma2= 1.84
# rho= 0.59 	mu1= -0.17 	mu2= 1.19 	sigma1= 2.24 	sigma2= 1.83
# rho= 0.59 	mu1= -0.17 	mu2= 1.20 	sigma1= 2.24 	sigma2= 1.83
# rho= 0.59 	mu1= -0.17 	mu2= 1.20 	sigma1= 2.24 	sigma2= 1.83
# rho= 0.59 	mu1= -0.17 	mu2= 1.20 	sigma1= 2.24 	sigma2= 1.83
# rho= 0.59 	mu1= -0.18 	mu2= 1.20 	sigma1= 2.24 	sigma2= 1.83
# rho= 0.59 	mu1= -0.18 	mu2= 1.20 	sigma1= 2.24 	sigma2= 1.83
# rho= 0.59 	mu1= -0.18 	mu2= 1.20 	sigma1= 2.24 	sigma2= 1.83
# rho= 0.59 	mu1= -0.18 	mu2= 1.20 	sigma1= 2.24 	sigma2= 1.83
# rho= 0.59 	mu1= -0.18 	mu2= 1.21 	sigma1= 2.24 	sigma2= 1.82
# rho= 0.59 	mu1= -0.18 	mu2= 1.21 	sigma1= 2.24 	sigma2= 1.82
# rho= 0.59 	mu1= -0.18 	mu2= 1.21 	sigma1= 2.24 	sigma2= 1.82
# rho= 0.59 	mu1= -0.18 	mu2= 1.21 	sigma1= 2.24 	sigma2= 1.82
# rho= 0.59 	mu1= -0.18 	mu2= 1.21 	sigma1= 2.24 	sigma2= 1.82
# rho= 0.59 	mu1= -0.18 	mu2= 1.21 	sigma1= 2.24 	sigma2= 1.82
# rho= 0.59 	mu1= -0.18 	mu2= 1.22 	sigma1= 2.24 	sigma2= 1.82
# rho= 0.59 	mu1= -0.18 	mu2= 1.22 	sigma1= 2.24 	sigma2= 1.82
# rho= 0.59 	mu1= -0.18 	mu2= 1.22 	sigma1= 2.24 	sigma2= 1.81
# rho= 0.59 	mu1= -0.19 	mu2= 1.22 	sigma1= 2.24 	sigma2= 1.81
# rho= 0.59 	mu1= -0.19 	mu2= 1.22 	sigma1= 2.24 	sigma2= 1.81
# rho= 0.59 	mu1= -0.19 	mu2= 1.22 	sigma1= 2.24 	sigma2= 1.81
# rho= 0.59 	mu1= -0.19 	mu2= 1.23 	sigma1= 2.24 	sigma2= 1.81
# rho= 0.59 	mu1= -0.19 	mu2= 1.23 	sigma1= 2.24 	sigma2= 1.81
# rho= 0.59 	mu1= -0.19 	mu2= 1.23 	sigma1= 2.24 	sigma2= 1.81
# rho= 0.59 	mu1= -0.19 	mu2= 1.23 	sigma1= 2.24 	sigma2= 1.80
# rho= 0.59 	mu1= -0.19 	mu2= 1.23 	sigma1= 2.24 	sigma2= 1.80
# rho= 0.59 	mu1= -0.19 	mu2= 1.23 	sigma1= 2.24 	sigma2= 1.80
# rho= 0.59 	mu1= -0.19 	mu2= 1.24 	sigma1= 2.24 	sigma2= 1.80
# rho= 0.59 	mu1= -0.19 	mu2= 1.24 	sigma1= 2.24 	sigma2= 1.80
# rho= 0.59 	mu1= -0.19 	mu2= 1.24 	sigma1= 2.24 	sigma2= 1.80
# rho= 0.60 	mu1= -0.20 	mu2= 1.24 	sigma1= 2.24 	sigma2= 1.80
# rho= 0.60 	mu1= -0.20 	mu2= 1.24 	sigma1= 2.24 	sigma2= 1.79
# rho= 0.60 	mu1= -0.20 	mu2= 1.25 	sigma1= 2.24 	sigma2= 1.79
# rho= 0.60 	mu1= -0.20 	mu2= 1.25 	sigma1= 2.24 	sigma2= 1.79
# rho= 0.60 	mu1= -0.20 	mu2= 1.25 	sigma1= 2.24 	sigma2= 1.79
# rho= 0.60 	mu1= -0.20 	mu2= 1.25 	sigma1= 2.24 	sigma2= 1.79
# rho= 0.60 	mu1= -0.20 	mu2= 1.25 	sigma1= 2.24 	sigma2= 1.79
# rho= 0.60 	mu1= -0.20 	mu2= 1.25 	sigma1= 2.24 	sigma2= 1.79
# rho= 0.60 	mu1= -0.20 	mu2= 1.26 	sigma1= 2.24 	sigma2= 1.78
# rho= 0.60 	mu1= -0.20 	mu2= 1.26 	sigma1= 2.24 	sigma2= 1.78
# rho= 0.60 	mu1= -0.20 	mu2= 1.26 	sigma1= 2.24 	sigma2= 1.78
# rho= 0.60 	mu1= -0.20 	mu2= 1.26 	sigma1= 2.24 	sigma2= 1.78
# rho= 0.60 	mu1= -0.21 	mu2= 1.26 	sigma1= 2.24 	sigma2= 1.78
# rho= 0.60 	mu1= -0.21 	mu2= 1.27 	sigma1= 2.24 	sigma2= 1.78
# rho= 0.60 	mu1= -0.21 	mu2= 1.27 	sigma1= 2.24 	sigma2= 1.77
# rho= 0.60 	mu1= -0.21 	mu2= 1.27 	sigma1= 2.23 	sigma2= 1.77
# rho= 0.60 	mu1= -0.21 	mu2= 1.27 	sigma1= 2.23 	sigma2= 1.77
# rho= 0.60 	mu1= -0.21 	mu2= 1.27 	sigma1= 2.23 	sigma2= 1.77
# rho= 0.60 	mu1= -0.21 	mu2= 1.28 	sigma1= 2.23 	sigma2= 1.77
# rho= 0.60 	mu1= -0.21 	mu2= 1.28 	sigma1= 2.23 	sigma2= 1.77
# rho= 0.60 	mu1= -0.21 	mu2= 1.28 	sigma1= 2.23 	sigma2= 1.76
# rho= 0.60 	mu1= -0.21 	mu2= 1.28 	sigma1= 2.23 	sigma2= 1.76
# rho= 0.60 	mu1= -0.22 	mu2= 1.28 	sigma1= 2.23 	sigma2= 1.76
# rho= 0.60 	mu1= -0.22 	mu2= 1.29 	sigma1= 2.23 	sigma2= 1.76
# rho= 0.60 	mu1= -0.22 	mu2= 1.29 	sigma1= 2.23 	sigma2= 1.76
# rho= 0.60 	mu1= -0.22 	mu2= 1.29 	sigma1= 2.23 	sigma2= 1.76
# rho= 0.60 	mu1= -0.22 	mu2= 1.29 	sigma1= 2.23 	sigma2= 1.75
# rho= 0.60 	mu1= -0.22 	mu2= 1.29 	sigma1= 2.23 	sigma2= 1.75
# rho= 0.60 	mu1= -0.22 	mu2= 1.30 	sigma1= 2.23 	sigma2= 1.75
# rho= 0.60 	mu1= -0.22 	mu2= 1.30 	sigma1= 2.23 	sigma2= 1.75
# rho= 0.60 	mu1= -0.22 	mu2= 1.30 	sigma1= 2.23 	sigma2= 1.75
# rho= 0.60 	mu1= -0.22 	mu2= 1.30 	sigma1= 2.23 	sigma2= 1.75
# rho= 0.60 	mu1= -0.22 	mu2= 1.30 	sigma1= 2.23 	sigma2= 1.74
# rho= 0.60 	mu1= -0.23 	mu2= 1.31 	sigma1= 2.23 	sigma2= 1.74
# rho= 0.60 	mu1= -0.23 	mu2= 1.31 	sigma1= 2.23 	sigma2= 1.74
# rho= 0.60 	mu1= -0.23 	mu2= 1.31 	sigma1= 2.23 	sigma2= 1.74
# rho= 0.60 	mu1= -0.23 	mu2= 1.31 	sigma1= 2.23 	sigma2= 1.74
# rho= 0.60 	mu1= -0.23 	mu2= 1.31 	sigma1= 2.23 	sigma2= 1.73
# rho= 0.60 	mu1= -0.23 	mu2= 1.32 	sigma1= 2.23 	sigma2= 1.73
# rho= 0.60 	mu1= -0.23 	mu2= 1.32 	sigma1= 2.23 	sigma2= 1.73
# rho= 0.60 	mu1= -0.23 	mu2= 1.32 	sigma1= 2.23 	sigma2= 1.73
# rho= 0.60 	mu1= -0.23 	mu2= 1.32 	sigma1= 2.23 	sigma2= 1.73
# rho= 0.60 	mu1= -0.24 	mu2= 1.33 	sigma1= 2.23 	sigma2= 1.72
# rho= 0.60 	mu1= -0.24 	mu2= 1.33 	sigma1= 2.23 	sigma2= 1.72
# rho= 0.60 	mu1= -0.24 	mu2= 1.33 	sigma1= 2.23 	sigma2= 1.72
# rho= 0.60 	mu1= -0.24 	mu2= 1.33 	sigma1= 2.23 	sigma2= 1.72
# rho= 0.60 	mu1= -0.24 	mu2= 1.34 	sigma1= 2.23 	sigma2= 1.72
# rho= 0.60 	mu1= -0.24 	mu2= 1.34 	sigma1= 2.23 	sigma2= 1.71
# rho= 0.60 	mu1= -0.24 	mu2= 1.34 	sigma1= 2.23 	sigma2= 1.71
# rho= 0.60 	mu1= -0.24 	mu2= 1.34 	sigma1= 2.23 	sigma2= 1.71
# rho= 0.60 	mu1= -0.24 	mu2= 1.34 	sigma1= 2.23 	sigma2= 1.71
# rho= 0.60 	mu1= -0.24 	mu2= 1.35 	sigma1= 2.23 	sigma2= 1.71
# rho= 0.60 	mu1= -0.25 	mu2= 1.35 	sigma1= 2.23 	sigma2= 1.70
# rho= 0.60 	mu1= -0.25 	mu2= 1.35 	sigma1= 2.23 	sigma2= 1.70
# rho= 0.60 	mu1= -0.25 	mu2= 1.35 	sigma1= 2.23 	sigma2= 1.70
# rho= 0.60 	mu1= -0.25 	mu2= 1.36 	sigma1= 2.23 	sigma2= 1.70
# rho= 0.60 	mu1= -0.25 	mu2= 1.36 	sigma1= 2.23 	sigma2= 1.70
# rho= 0.60 	mu1= -0.25 	mu2= 1.36 	sigma1= 2.23 	sigma2= 1.69
# rho= 0.60 	mu1= -0.25 	mu2= 1.36 	sigma1= 2.23 	sigma2= 1.69
# rho= 0.60 	mu1= -0.25 	mu2= 1.37 	sigma1= 2.23 	sigma2= 1.69
# rho= 0.60 	mu1= -0.25 	mu2= 1.37 	sigma1= 2.23 	sigma2= 1.69
# rho= 0.60 	mu1= -0.26 	mu2= 1.37 	sigma1= 2.23 	sigma2= 1.68
# rho= 0.60 	mu1= -0.26 	mu2= 1.37 	sigma1= 2.23 	sigma2= 1.68
# rho= 0.60 	mu1= -0.26 	mu2= 1.38 	sigma1= 2.23 	sigma2= 1.68
# rho= 0.61 	mu1= -0.26 	mu2= 1.38 	sigma1= 2.23 	sigma2= 1.68
# rho= 0.61 	mu1= -0.26 	mu2= 1.38 	sigma1= 2.23 	sigma2= 1.68
# rho= 0.61 	mu1= -0.26 	mu2= 1.38 	sigma1= 2.23 	sigma2= 1.67
# rho= 0.61 	mu1= -0.26 	mu2= 1.39 	sigma1= 2.23 	sigma2= 1.67
# rho= 0.61 	mu1= -0.26 	mu2= 1.39 	sigma1= 2.23 	sigma2= 1.67
# rho= 0.61 	mu1= -0.27 	mu2= 1.39 	sigma1= 2.22 	sigma2= 1.67
# rho= 0.61 	mu1= -0.27 	mu2= 1.39 	sigma1= 2.22 	sigma2= 1.66
# rho= 0.61 	mu1= -0.27 	mu2= 1.40 	sigma1= 2.22 	sigma2= 1.66
# rho= 0.61 	mu1= -0.27 	mu2= 1.40 	sigma1= 2.22 	sigma2= 1.66
# rho= 0.61 	mu1= -0.27 	mu2= 1.40 	sigma1= 2.22 	sigma2= 1.66
# rho= 0.61 	mu1= -0.27 	mu2= 1.41 	sigma1= 2.22 	sigma2= 1.65
# rho= 0.61 	mu1= -0.27 	mu2= 1.41 	sigma1= 2.22 	sigma2= 1.65
# rho= 0.61 	mu1= -0.27 	mu2= 1.41 	sigma1= 2.22 	sigma2= 1.65
# rho= 0.61 	mu1= -0.28 	mu2= 1.41 	sigma1= 2.22 	sigma2= 1.65
# rho= 0.61 	mu1= -0.28 	mu2= 1.42 	sigma1= 2.22 	sigma2= 1.64
# rho= 0.61 	mu1= -0.28 	mu2= 1.42 	sigma1= 2.22 	sigma2= 1.64
# rho= 0.61 	mu1= -0.28 	mu2= 1.42 	sigma1= 2.22 	sigma2= 1.64
# rho= 0.61 	mu1= -0.28 	mu2= 1.43 	sigma1= 2.22 	sigma2= 1.63
# rho= 0.61 	mu1= -0.28 	mu2= 1.43 	sigma1= 2.22 	sigma2= 1.63
# rho= 0.61 	mu1= -0.28 	mu2= 1.43 	sigma1= 2.22 	sigma2= 1.63
# rho= 0.61 	mu1= -0.28 	mu2= 1.43 	sigma1= 2.22 	sigma2= 1.63
# rho= 0.61 	mu1= -0.29 	mu2= 1.44 	sigma1= 2.22 	sigma2= 1.62
# rho= 0.61 	mu1= -0.29 	mu2= 1.44 	sigma1= 2.22 	sigma2= 1.62
# rho= 0.61 	mu1= -0.29 	mu2= 1.44 	sigma1= 2.22 	sigma2= 1.62
# rho= 0.61 	mu1= -0.29 	mu2= 1.45 	sigma1= 2.22 	sigma2= 1.61
# rho= 0.61 	mu1= -0.29 	mu2= 1.45 	sigma1= 2.22 	sigma2= 1.61
# rho= 0.61 	mu1= -0.29 	mu2= 1.45 	sigma1= 2.22 	sigma2= 1.61
# rho= 0.61 	mu1= -0.29 	mu2= 1.46 	sigma1= 2.22 	sigma2= 1.61
# rho= 0.61 	mu1= -0.30 	mu2= 1.46 	sigma1= 2.22 	sigma2= 1.60
# rho= 0.61 	mu1= -0.30 	mu2= 1.46 	sigma1= 2.22 	sigma2= 1.60
# rho= 0.61 	mu1= -0.30 	mu2= 1.46 	sigma1= 2.22 	sigma2= 1.60
# rho= 0.61 	mu1= -0.30 	mu2= 1.47 	sigma1= 2.22 	sigma2= 1.59
# rho= 0.61 	mu1= -0.30 	mu2= 1.47 	sigma1= 2.22 	sigma2= 1.59
# rho= 0.61 	mu1= -0.30 	mu2= 1.47 	sigma1= 2.22 	sigma2= 1.59
# rho= 0.61 	mu1= -0.30 	mu2= 1.48 	sigma1= 2.22 	sigma2= 1.58
# rho= 0.61 	mu1= -0.31 	mu2= 1.48 	sigma1= 2.22 	sigma2= 1.58
# rho= 0.61 	mu1= -0.31 	mu2= 1.48 	sigma1= 2.21 	sigma2= 1.58
# rho= 0.61 	mu1= -0.31 	mu2= 1.49 	sigma1= 2.21 	sigma2= 1.57
# rho= 0.61 	mu1= -0.31 	mu2= 1.49 	sigma1= 2.21 	sigma2= 1.57
# rho= 0.61 	mu1= -0.31 	mu2= 1.49 	sigma1= 2.21 	sigma2= 1.57
# rho= 0.61 	mu1= -0.31 	mu2= 1.50 	sigma1= 2.21 	sigma2= 1.56
# rho= 0.61 	mu1= -0.31 	mu2= 1.50 	sigma1= 2.21 	sigma2= 1.56
# rho= 0.61 	mu1= -0.32 	mu2= 1.50 	sigma1= 2.21 	sigma2= 1.56
# rho= 0.61 	mu1= -0.32 	mu2= 1.51 	sigma1= 2.21 	sigma2= 1.55
# rho= 0.61 	mu1= -0.32 	mu2= 1.51 	sigma1= 2.21 	sigma2= 1.55
# rho= 0.61 	mu1= -0.32 	mu2= 1.52 	sigma1= 2.21 	sigma2= 1.55
# rho= 0.61 	mu1= -0.32 	mu2= 1.52 	sigma1= 2.21 	sigma2= 1.54
# rho= 0.61 	mu1= -0.32 	mu2= 1.52 	sigma1= 2.21 	sigma2= 1.54
# rho= 0.61 	mu1= -0.33 	mu2= 1.53 	sigma1= 2.21 	sigma2= 1.54
# rho= 0.61 	mu1= -0.33 	mu2= 1.53 	sigma1= 2.21 	sigma2= 1.53
# rho= 0.61 	mu1= -0.33 	mu2= 1.53 	sigma1= 2.21 	sigma2= 1.53
# rho= 0.61 	mu1= -0.33 	mu2= 1.54 	sigma1= 2.21 	sigma2= 1.52
# rho= 0.61 	mu1= -0.33 	mu2= 1.54 	sigma1= 2.21 	sigma2= 1.52
# rho= 0.61 	mu1= -0.33 	mu2= 1.54 	sigma1= 2.21 	sigma2= 1.52
# rho= 0.61 	mu1= -0.34 	mu2= 1.55 	sigma1= 2.21 	sigma2= 1.51
# rho= 0.61 	mu1= -0.34 	mu2= 1.55 	sigma1= 2.21 	sigma2= 1.51
# rho= 0.61 	mu1= -0.34 	mu2= 1.56 	sigma1= 2.20 	sigma2= 1.50
# rho= 0.61 	mu1= -0.34 	mu2= 1.56 	sigma1= 2.20 	sigma2= 1.50
# rho= 0.61 	mu1= -0.34 	mu2= 1.56 	sigma1= 2.20 	sigma2= 1.50
# rho= 0.61 	mu1= -0.34 	mu2= 1.57 	sigma1= 2.20 	sigma2= 1.49
# rho= 0.61 	mu1= -0.35 	mu2= 1.57 	sigma1= 2.20 	sigma2= 1.49
# rho= 0.61 	mu1= -0.35 	mu2= 1.58 	sigma1= 2.20 	sigma2= 1.48
# rho= 0.61 	mu1= -0.35 	mu2= 1.58 	sigma1= 2.20 	sigma2= 1.48
# rho= 0.61 	mu1= -0.35 	mu2= 1.58 	sigma1= 2.20 	sigma2= 1.48
# rho= 0.61 	mu1= -0.35 	mu2= 1.59 	sigma1= 2.20 	sigma2= 1.47
# rho= 0.61 	mu1= -0.36 	mu2= 1.59 	sigma1= 2.20 	sigma2= 1.47
# rho= 0.61 	mu1= -0.36 	mu2= 1.60 	sigma1= 2.20 	sigma2= 1.46
# rho= 0.61 	mu1= -0.36 	mu2= 1.60 	sigma1= 2.20 	sigma2= 1.46
# rho= 0.61 	mu1= -0.36 	mu2= 1.60 	sigma1= 2.20 	sigma2= 1.45
# rho= 0.61 	mu1= -0.36 	mu2= 1.61 	sigma1= 2.20 	sigma2= 1.45
# rho= 0.61 	mu1= -0.37 	mu2= 1.61 	sigma1= 2.20 	sigma2= 1.44
# rho= 0.61 	mu1= -0.37 	mu2= 1.62 	sigma1= 2.20 	sigma2= 1.44
# rho= 0.61 	mu1= -0.37 	mu2= 1.62 	sigma1= 2.19 	sigma2= 1.43
# rho= 0.61 	mu1= -0.37 	mu2= 1.63 	sigma1= 2.19 	sigma2= 1.43
# rho= 0.61 	mu1= -0.37 	mu2= 1.63 	sigma1= 2.19 	sigma2= 1.42
# rho= 0.61 	mu1= -0.38 	mu2= 1.64 	sigma1= 2.19 	sigma2= 1.42
# rho= 0.61 	mu1= -0.38 	mu2= 1.64 	sigma1= 2.19 	sigma2= 1.41
# rho= 0.61 	mu1= -0.38 	mu2= 1.64 	sigma1= 2.19 	sigma2= 1.41
# rho= 0.61 	mu1= -0.38 	mu2= 1.65 	sigma1= 2.19 	sigma2= 1.40
# rho= 0.61 	mu1= -0.38 	mu2= 1.65 	sigma1= 2.19 	sigma2= 1.40
# rho= 0.61 	mu1= -0.39 	mu2= 1.66 	sigma1= 2.19 	sigma2= 1.39
# rho= 0.61 	mu1= -0.39 	mu2= 1.66 	sigma1= 2.19 	sigma2= 1.39
# rho= 0.61 	mu1= -0.39 	mu2= 1.67 	sigma1= 2.19 	sigma2= 1.38
# rho= 0.61 	mu1= -0.39 	mu2= 1.67 	sigma1= 2.19 	sigma2= 1.38
# rho= 0.61 	mu1= -0.39 	mu2= 1.68 	sigma1= 2.19 	sigma2= 1.37
# rho= 0.61 	mu1= -0.40 	mu2= 1.68 	sigma1= 2.18 	sigma2= 1.37
# rho= 0.61 	mu1= -0.40 	mu2= 1.69 	sigma1= 2.18 	sigma2= 1.36
# rho= 0.61 	mu1= -0.40 	mu2= 1.69 	sigma1= 2.18 	sigma2= 1.35
# rho= 0.61 	mu1= -0.40 	mu2= 1.70 	sigma1= 2.18 	sigma2= 1.35
# rho= 0.61 	mu1= -0.41 	mu2= 1.70 	sigma1= 2.18 	sigma2= 1.34
# rho= 0.61 	mu1= -0.41 	mu2= 1.71 	sigma1= 2.18 	sigma2= 1.34
# rho= 0.61 	mu1= -0.41 	mu2= 1.71 	sigma1= 2.18 	sigma2= 1.33
# rho= 0.61 	mu1= -0.41 	mu2= 1.72 	sigma1= 2.18 	sigma2= 1.32
# rho= 0.61 	mu1= -0.41 	mu2= 1.72 	sigma1= 2.18 	sigma2= 1.32
# rho= 0.61 	mu1= -0.42 	mu2= 1.73 	sigma1= 2.18 	sigma2= 1.31
# rho= 0.61 	mu1= -0.42 	mu2= 1.73 	sigma1= 2.17 	sigma2= 1.31
# rho= 0.61 	mu1= -0.42 	mu2= 1.74 	sigma1= 2.17 	sigma2= 1.30
# rho= 0.61 	mu1= -0.42 	mu2= 1.74 	sigma1= 2.17 	sigma2= 1.29
# rho= 0.61 	mu1= -0.43 	mu2= 1.75 	sigma1= 2.17 	sigma2= 1.29
# rho= 0.61 	mu1= -0.43 	mu2= 1.76 	sigma1= 2.17 	sigma2= 1.28
# rho= 0.61 	mu1= -0.43 	mu2= 1.76 	sigma1= 2.17 	sigma2= 1.27
# rho= 0.61 	mu1= -0.43 	mu2= 1.77 	sigma1= 2.17 	sigma2= 1.27
# rho= 0.61 	mu1= -0.44 	mu2= 1.77 	sigma1= 2.17 	sigma2= 1.26
# rho= 0.61 	mu1= -0.44 	mu2= 1.78 	sigma1= 2.17 	sigma2= 1.25
# rho= 0.61 	mu1= -0.44 	mu2= 1.78 	sigma1= 2.16 	sigma2= 1.25
# rho= 0.61 	mu1= -0.44 	mu2= 1.79 	sigma1= 2.16 	sigma2= 1.24
# rho= 0.61 	mu1= -0.45 	mu2= 1.79 	sigma1= 2.16 	sigma2= 1.23
# rho= 0.61 	mu1= -0.45 	mu2= 1.80 	sigma1= 2.16 	sigma2= 1.23
# rho= 0.61 	mu1= -0.45 	mu2= 1.81 	sigma1= 2.16 	sigma2= 1.22
# rho= 0.61 	mu1= -0.46 	mu2= 1.81 	sigma1= 2.16 	sigma2= 1.21
# rho= 0.61 	mu1= -0.46 	mu2= 1.82 	sigma1= 2.16 	sigma2= 1.21
# rho= 0.60 	mu1= -0.46 	mu2= 1.82 	sigma1= 2.16 	sigma2= 1.20
# rho= 0.60 	mu1= -0.46 	mu2= 1.83 	sigma1= 2.15 	sigma2= 1.19
# rho= 0.60 	mu1= -0.47 	mu2= 1.84 	sigma1= 2.15 	sigma2= 1.18
# rho= 0.60 	mu1= -0.47 	mu2= 1.84 	sigma1= 2.15 	sigma2= 1.18
# rho= 0.60 	mu1= -0.47 	mu2= 1.85 	sigma1= 2.15 	sigma2= 1.17
# rho= 0.60 	mu1= -0.47 	mu2= 1.85 	sigma1= 2.15 	sigma2= 1.16
# rho= 0.60 	mu1= -0.48 	mu2= 1.86 	sigma1= 2.15 	sigma2= 1.16
# rho= 0.60 	mu1= -0.48 	mu2= 1.87 	sigma1= 2.15 	sigma2= 1.15
# rho= 0.60 	mu1= -0.48 	mu2= 1.87 	sigma1= 2.15 	sigma2= 1.14
# rho= 0.60 	mu1= -0.49 	mu2= 1.88 	sigma1= 2.14 	sigma2= 1.13
# rho= 0.60 	mu1= -0.49 	mu2= 1.88 	sigma1= 2.14 	sigma2= 1.13
# rho= 0.60 	mu1= -0.49 	mu2= 1.89 	sigma1= 2.14 	sigma2= 1.12
# rho= 0.60 	mu1= -0.49 	mu2= 1.90 	sigma1= 2.14 	sigma2= 1.11
# rho= 0.60 	mu1= -0.50 	mu2= 1.90 	sigma1= 2.14 	sigma2= 1.10
# rho= 0.60 	mu1= -0.50 	mu2= 1.91 	sigma1= 2.14 	sigma2= 1.10
# rho= 0.60 	mu1= -0.50 	mu2= 1.91 	sigma1= 2.13 	sigma2= 1.09
# rho= 0.60 	mu1= -0.51 	mu2= 1.92 	sigma1= 2.13 	sigma2= 1.08
# rho= 0.60 	mu1= -0.51 	mu2= 1.93 	sigma1= 2.13 	sigma2= 1.07
# rho= 0.60 	mu1= -0.51 	mu2= 1.93 	sigma1= 2.13 	sigma2= 1.07
# rho= 0.60 	mu1= -0.52 	mu2= 1.94 	sigma1= 2.13 	sigma2= 1.06
# rho= 0.60 	mu1= -0.52 	mu2= 1.95 	sigma1= 2.13 	sigma2= 1.05
# rho= 0.60 	mu1= -0.52 	mu2= 1.95 	sigma1= 2.12 	sigma2= 1.05
# rho= 0.60 	mu1= -0.52 	mu2= 1.96 	sigma1= 2.12 	sigma2= 1.04
# rho= 0.60 	mu1= -0.53 	mu2= 1.96 	sigma1= 2.12 	sigma2= 1.03
# rho= 0.60 	mu1= -0.53 	mu2= 1.97 	sigma1= 2.12 	sigma2= 1.03
# rho= 0.60 	mu1= -0.53 	mu2= 1.98 	sigma1= 2.12 	sigma2= 1.02
# rho= 0.60 	mu1= -0.54 	mu2= 1.98 	sigma1= 2.12 	sigma2= 1.01
# rho= 0.60 	mu1= -0.54 	mu2= 1.99 	sigma1= 2.11 	sigma2= 1.00
# rho= 0.60 	mu1= -0.54 	mu2= 1.99 	sigma1= 2.11 	sigma2= 1.00
# rho= 0.60 	mu1= -0.55 	mu2= 2.00 	sigma1= 2.11 	sigma2= 0.99
# rho= 0.60 	mu1= -0.55 	mu2= 2.01 	sigma1= 2.11 	sigma2= 0.98
# rho= 0.60 	mu1= -0.55 	mu2= 2.01 	sigma1= 2.11 	sigma2= 0.98
# rho= 0.60 	mu1= -0.56 	mu2= 2.02 	sigma1= 2.11 	sigma2= 0.97
# rho= 0.60 	mu1= -0.56 	mu2= 2.02 	sigma1= 2.10 	sigma2= 0.97
# rho= 0.60 	mu1= -0.56 	mu2= 2.03 	sigma1= 2.10 	sigma2= 0.96
# rho= 0.60 	mu1= -0.56 	mu2= 2.03 	sigma1= 2.10 	sigma2= 0.95
# rho= 0.60 	mu1= -0.57 	mu2= 2.04 	sigma1= 2.10 	sigma2= 0.95
# rho= 0.60 	mu1= -0.57 	mu2= 2.05 	sigma1= 2.10 	sigma2= 0.94
# rho= 0.60 	mu1= -0.57 	mu2= 2.05 	sigma1= 2.09 	sigma2= 0.94
# rho= 0.60 	mu1= -0.58 	mu2= 2.06 	sigma1= 2.09 	sigma2= 0.93
# rho= 0.60 	mu1= -0.58 	mu2= 2.06 	sigma1= 2.09 	sigma2= 0.93
# rho= 0.60 	mu1= -0.58 	mu2= 2.07 	sigma1= 2.09 	sigma2= 0.92
# rho= 0.60 	mu1= -0.59 	mu2= 2.07 	sigma1= 2.09 	sigma2= 0.92
# rho= 0.60 	mu1= -0.59 	mu2= 2.08 	sigma1= 2.08 	sigma2= 0.91
# rho= 0.60 	mu1= -0.59 	mu2= 2.08 	sigma1= 2.08 	sigma2= 0.91
# rho= 0.60 	mu1= -0.59 	mu2= 2.09 	sigma1= 2.08 	sigma2= 0.90
# rho= 0.60 	mu1= -0.60 	mu2= 2.09 	sigma1= 2.08 	sigma2= 0.90
# rho= 0.60 	mu1= -0.60 	mu2= 2.10 	sigma1= 2.08 	sigma2= 0.89
# rho= 0.60 	mu1= -0.60 	mu2= 2.10 	sigma1= 2.08 	sigma2= 0.89
# rho= 0.60 	mu1= -0.61 	mu2= 2.11 	sigma1= 2.07 	sigma2= 0.89
# rho= 0.60 	mu1= -0.61 	mu2= 2.11 	sigma1= 2.07 	sigma2= 0.88
# rho= 0.60 	mu1= -0.61 	mu2= 2.12 	sigma1= 2.07 	sigma2= 0.88
# rho= 0.60 	mu1= -0.61 	mu2= 2.12 	sigma1= 2.07 	sigma2= 0.87
# rho= 0.60 	mu1= -0.62 	mu2= 2.12 	sigma1= 2.07 	sigma2= 0.87
# rho= 0.60 	mu1= -0.62 	mu2= 2.13 	sigma1= 2.06 	sigma2= 0.87
# rho= 0.60 	mu1= -0.62 	mu2= 2.13 	sigma1= 2.06 	sigma2= 0.87
# rho= 0.60 	mu1= -0.63 	mu2= 2.14 	sigma1= 2.06 	sigma2= 0.86
# rho= 0.60 	mu1= -0.63 	mu2= 2.14 	sigma1= 2.06 	sigma2= 0.86
# rho= 0.60 	mu1= -0.63 	mu2= 2.14 	sigma1= 2.06 	sigma2= 0.86
# rho= 0.60 	mu1= -0.63 	mu2= 2.15 	sigma1= 2.05 	sigma2= 0.85
# rho= 0.60 	mu1= -0.64 	mu2= 2.15 	sigma1= 2.05 	sigma2= 0.85
# rho= 0.60 	mu1= -0.64 	mu2= 2.16 	sigma1= 2.05 	sigma2= 0.85
# rho= 0.60 	mu1= -0.64 	mu2= 2.16 	sigma1= 2.05 	sigma2= 0.85
# rho= 0.60 	mu1= -0.64 	mu2= 2.16 	sigma1= 2.05 	sigma2= 0.84
# rho= 0.60 	mu1= -0.65 	mu2= 2.17 	sigma1= 2.04 	sigma2= 0.84
# rho= 0.60 	mu1= -0.65 	mu2= 2.17 	sigma1= 2.04 	sigma2= 0.84
# rho= 0.60 	mu1= -0.65 	mu2= 2.17 	sigma1= 2.04 	sigma2= 0.84
# rho= 0.60 	mu1= -0.66 	mu2= 2.18 	sigma1= 2.04 	sigma2= 0.84
# rho= 0.60 	mu1= -0.66 	mu2= 2.18 	sigma1= 2.04 	sigma2= 0.83
# rho= 0.60 	mu1= -0.66 	mu2= 2.18 	sigma1= 2.04 	sigma2= 0.83
# rho= 0.60 	mu1= -0.66 	mu2= 2.19 	sigma1= 2.03 	sigma2= 0.83
# rho= 0.60 	mu1= -0.67 	mu2= 2.19 	sigma1= 2.03 	sigma2= 0.83
# rho= 0.60 	mu1= -0.67 	mu2= 2.19 	sigma1= 2.03 	sigma2= 0.83
# rho= 0.60 	mu1= -0.67 	mu2= 2.19 	sigma1= 2.03 	sigma2= 0.83
# rho= 0.60 	mu1= -0.67 	mu2= 2.20 	sigma1= 2.03 	sigma2= 0.83
# rho= 0.60 	mu1= -0.68 	mu2= 2.20 	sigma1= 2.02 	sigma2= 0.83
# rho= 0.60 	mu1= -0.68 	mu2= 2.20 	sigma1= 2.02 	sigma2= 0.82
# rho= 0.60 	mu1= -0.68 	mu2= 2.20 	sigma1= 2.02 	sigma2= 0.82
# rho= 0.60 	mu1= -0.68 	mu2= 2.21 	sigma1= 2.02 	sigma2= 0.82
# rho= 0.59 	mu1= -0.69 	mu2= 2.21 	sigma1= 2.02 	sigma2= 0.82
# rho= 0.59 	mu1= -0.69 	mu2= 2.21 	sigma1= 2.01 	sigma2= 0.82
# rho= 0.59 	mu1= -0.69 	mu2= 2.21 	sigma1= 2.01 	sigma2= 0.82
# rho= 0.59 	mu1= -0.69 	mu2= 2.21 	sigma1= 2.01 	sigma2= 0.82
# rho= 0.59 	mu1= -0.70 	mu2= 2.22 	sigma1= 2.01 	sigma2= 0.82
# rho= 0.59 	mu1= -0.70 	mu2= 2.22 	sigma1= 2.01 	sigma2= 0.82
# rho= 0.59 	mu1= -0.70 	mu2= 2.22 	sigma1= 2.01 	sigma2= 0.82
# rho= 0.59 	mu1= -0.70 	mu2= 2.22 	sigma1= 2.00 	sigma2= 0.82
# rho= 0.59 	mu1= -0.71 	mu2= 2.22 	sigma1= 2.00 	sigma2= 0.82
# rho= 0.59 	mu1= -0.71 	mu2= 2.23 	sigma1= 2.00 	sigma2= 0.82
# rho= 0.59 	mu1= -0.71 	mu2= 2.23 	sigma1= 2.00 	sigma2= 0.82
# rho= 0.59 	mu1= -0.71 	mu2= 2.23 	sigma1= 2.00 	sigma2= 0.82
# rho= 0.59 	mu1= -0.72 	mu2= 2.23 	sigma1= 1.99 	sigma2= 0.82
# rho= 0.59 	mu1= -0.72 	mu2= 2.23 	sigma1= 1.99 	sigma2= 0.81
# rho= 0.59 	mu1= -0.72 	mu2= 2.23 	sigma1= 1.99 	sigma2= 0.81
# rho= 0.59 	mu1= -0.72 	mu2= 2.24 	sigma1= 1.99 	sigma2= 0.81
# rho= 0.59 	mu1= -0.73 	mu2= 2.24 	sigma1= 1.99 	sigma2= 0.81
# rho= 0.59 	mu1= -0.73 	mu2= 2.24 	sigma1= 1.98 	sigma2= 0.81
# rho= 0.59 	mu1= -0.73 	mu2= 2.24 	sigma1= 1.98 	sigma2= 0.81
# rho= 0.59 	mu1= -0.73 	mu2= 2.24 	sigma1= 1.98 	sigma2= 0.81
# rho= 0.59 	mu1= -0.73 	mu2= 2.24 	sigma1= 1.98 	sigma2= 0.81
# rho= 0.59 	mu1= -0.74 	mu2= 2.24 	sigma1= 1.98 	sigma2= 0.81
# rho= 0.59 	mu1= -0.74 	mu2= 2.24 	sigma1= 1.98 	sigma2= 0.81
# rho= 0.59 	mu1= -0.74 	mu2= 2.25 	sigma1= 1.97 	sigma2= 0.81
# rho= 0.59 	mu1= -0.74 	mu2= 2.25 	sigma1= 1.97 	sigma2= 0.81
# rho= 0.59 	mu1= -0.75 	mu2= 2.25 	sigma1= 1.97 	sigma2= 0.81
# rho= 0.59 	mu1= -0.75 	mu2= 2.25 	sigma1= 1.97 	sigma2= 0.81
# rho= 0.59 	mu1= -0.75 	mu2= 2.25 	sigma1= 1.97 	sigma2= 0.81
# rho= 0.59 	mu1= -0.75 	mu2= 2.25 	sigma1= 1.96 	sigma2= 0.81
# rho= 0.59 	mu1= -0.76 	mu2= 2.25 	sigma1= 1.96 	sigma2= 0.81
# rho= 0.59 	mu1= -0.76 	mu2= 2.25 	sigma1= 1.96 	sigma2= 0.81
# rho= 0.59 	mu1= -0.76 	mu2= 2.25 	sigma1= 1.96 	sigma2= 0.81
# rho= 0.59 	mu1= -0.76 	mu2= 2.25 	sigma1= 1.96 	sigma2= 0.81
# rho= 0.59 	mu1= -0.77 	mu2= 2.26 	sigma1= 1.96 	sigma2= 0.81
# rho= 0.59 	mu1= -0.77 	mu2= 2.26 	sigma1= 1.95 	sigma2= 0.81
# rho= 0.59 	mu1= -0.77 	mu2= 2.26 	sigma1= 1.95 	sigma2= 0.81
# rho= 0.58 	mu1= -0.77 	mu2= 2.26 	sigma1= 1.95 	sigma2= 0.81
# rho= 0.58 	mu1= -0.78 	mu2= 2.26 	sigma1= 1.95 	sigma2= 0.81
# rho= 0.58 	mu1= -0.78 	mu2= 2.26 	sigma1= 1.95 	sigma2= 0.81
# rho= 0.58 	mu1= -0.78 	mu2= 2.26 	sigma1= 1.94 	sigma2= 0.82
# rho= 0.58 	mu1= -0.78 	mu2= 2.26 	sigma1= 1.94 	sigma2= 0.82
# rho= 0.58 	mu1= -0.79 	mu2= 2.26 	sigma1= 1.94 	sigma2= 0.82
# rho= 0.58 	mu1= -0.79 	mu2= 2.26 	sigma1= 1.94 	sigma2= 0.82
# rho= 0.58 	mu1= -0.79 	mu2= 2.26 	sigma1= 1.94 	sigma2= 0.82
# rho= 0.58 	mu1= -0.79 	mu2= 2.26 	sigma1= 1.94 	sigma2= 0.82
# rho= 0.58 	mu1= -0.79 	mu2= 2.26 	sigma1= 1.93 	sigma2= 0.82
# rho= 0.58 	mu1= -0.80 	mu2= 2.26 	sigma1= 1.93 	sigma2= 0.82
# rho= 0.58 	mu1= -0.80 	mu2= 2.26 	sigma1= 1.93 	sigma2= 0.82
# rho= 0.58 	mu1= -0.80 	mu2= 2.26 	sigma1= 1.93 	sigma2= 0.82
# rho= 0.58 	mu1= -0.80 	mu2= 2.27 	sigma1= 1.93 	sigma2= 0.82
# rho= 0.58 	mu1= -0.81 	mu2= 2.27 	sigma1= 1.92 	sigma2= 0.82
# rho= 0.58 	mu1= -0.81 	mu2= 2.27 	sigma1= 1.92 	sigma2= 0.82
# rho= 0.58 	mu1= -0.81 	mu2= 2.27 	sigma1= 1.92 	sigma2= 0.82
# rho= 0.58 	mu1= -0.81 	mu2= 2.27 	sigma1= 1.92 	sigma2= 0.82
# rho= 0.58 	mu1= -0.82 	mu2= 2.27 	sigma1= 1.92 	sigma2= 0.82
# rho= 0.58 	mu1= -0.82 	mu2= 2.27 	sigma1= 1.92 	sigma2= 0.82
# rho= 0.58 	mu1= -0.82 	mu2= 2.27 	sigma1= 1.91 	sigma2= 0.82
# rho= 0.58 	mu1= -0.82 	mu2= 2.27 	sigma1= 1.91 	sigma2= 0.82
# rho= 0.58 	mu1= -0.83 	mu2= 2.27 	sigma1= 1.91 	sigma2= 0.82
# rho= 0.58 	mu1= -0.83 	mu2= 2.27 	sigma1= 1.91 	sigma2= 0.82
# rho= 0.58 	mu1= -0.83 	mu2= 2.27 	sigma1= 1.91 	sigma2= 0.82
# rho= 0.57 	mu1= -0.83 	mu2= 2.27 	sigma1= 1.90 	sigma2= 0.82
# rho= 0.57 	mu1= -0.84 	mu2= 2.27 	sigma1= 1.90 	sigma2= 0.82
# rho= 0.57 	mu1= -0.84 	mu2= 2.27 	sigma1= 1.90 	sigma2= 0.82
# rho= 0.57 	mu1= -0.84 	mu2= 2.27 	sigma1= 1.90 	sigma2= 0.82
# rho= 0.57 	mu1= -0.84 	mu2= 2.27 	sigma1= 1.90 	sigma2= 0.82
# rho= 0.57 	mu1= -0.85 	mu2= 2.27 	sigma1= 1.90 	sigma2= 0.82
# rho= 0.57 	mu1= -0.85 	mu2= 2.27 	sigma1= 1.89 	sigma2= 0.82
# rho= 0.57 	mu1= -0.85 	mu2= 2.27 	sigma1= 1.89 	sigma2= 0.82
# rho= 0.57 	mu1= -0.85 	mu2= 2.27 	sigma1= 1.89 	sigma2= 0.82
# rho= 0.57 	mu1= -0.86 	mu2= 2.27 	sigma1= 1.89 	sigma2= 0.82
# rho= 0.57 	mu1= -0.86 	mu2= 2.27 	sigma1= 1.89 	sigma2= 0.82
# rho= 0.57 	mu1= -0.86 	mu2= 2.27 	sigma1= 1.88 	sigma2= 0.82
# rho= 0.57 	mu1= -0.86 	mu2= 2.27 	sigma1= 1.88 	sigma2= 0.83
# rho= 0.57 	mu1= -0.87 	mu2= 2.27 	sigma1= 1.88 	sigma2= 0.83
# rho= 0.57 	mu1= -0.87 	mu2= 2.27 	sigma1= 1.88 	sigma2= 0.83
# rho= 0.57 	mu1= -0.87 	mu2= 2.27 	sigma1= 1.88 	sigma2= 0.83
# rho= 0.57 	mu1= -0.87 	mu2= 2.27 	sigma1= 1.88 	sigma2= 0.83
# rho= 0.57 	mu1= -0.88 	mu2= 2.27 	sigma1= 1.87 	sigma2= 0.83
# rho= 0.57 	mu1= -0.88 	mu2= 2.27 	sigma1= 1.87 	sigma2= 0.83
# rho= 0.57 	mu1= -0.88 	mu2= 2.27 	sigma1= 1.87 	sigma2= 0.83
# rho= 0.57 	mu1= -0.88 	mu2= 2.27 	sigma1= 1.87 	sigma2= 0.83
# rho= 0.57 	mu1= -0.89 	mu2= 2.27 	sigma1= 1.87 	sigma2= 0.83
# rho= 0.57 	mu1= -0.89 	mu2= 2.27 	sigma1= 1.86 	sigma2= 0.83
# rho= 0.56 	mu1= -0.89 	mu2= 2.27 	sigma1= 1.86 	sigma2= 0.83
# rho= 0.56 	mu1= -0.89 	mu2= 2.27 	sigma1= 1.86 	sigma2= 0.83
# rho= 0.56 	mu1= -0.90 	mu2= 2.27 	sigma1= 1.86 	sigma2= 0.83
# rho= 0.56 	mu1= -0.90 	mu2= 2.27 	sigma1= 1.86 	sigma2= 0.83
# rho= 0.56 	mu1= -0.90 	mu2= 2.27 	sigma1= 1.86 	sigma2= 0.83
# rho= 0.56 	mu1= -0.90 	mu2= 2.27 	sigma1= 1.85 	sigma2= 0.83
# rho= 0.56 	mu1= -0.91 	mu2= 2.27 	sigma1= 1.85 	sigma2= 0.83
# rho= 0.56 	mu1= -0.91 	mu2= 2.27 	sigma1= 1.85 	sigma2= 0.83
# rho= 0.56 	mu1= -0.91 	mu2= 2.27 	sigma1= 1.85 	sigma2= 0.83
# rho= 0.56 	mu1= -0.91 	mu2= 2.27 	sigma1= 1.85 	sigma2= 0.83
# rho= 0.56 	mu1= -0.92 	mu2= 2.27 	sigma1= 1.84 	sigma2= 0.83
# rho= 0.56 	mu1= -0.92 	mu2= 2.27 	sigma1= 1.84 	sigma2= 0.83
# rho= 0.56 	mu1= -0.92 	mu2= 2.27 	sigma1= 1.84 	sigma2= 0.83
# rho= 0.56 	mu1= -0.92 	mu2= 2.27 	sigma1= 1.84 	sigma2= 0.83
# rho= 0.56 	mu1= -0.93 	mu2= 2.27 	sigma1= 1.84 	sigma2= 0.83
# rho= 0.56 	mu1= -0.93 	mu2= 2.27 	sigma1= 1.84 	sigma2= 0.83
# rho= 0.56 	mu1= -0.93 	mu2= 2.27 	sigma1= 1.83 	sigma2= 0.83
# rho= 0.56 	mu1= -0.93 	mu2= 2.27 	sigma1= 1.83 	sigma2= 0.84
# rho= 0.56 	mu1= -0.94 	mu2= 2.27 	sigma1= 1.83 	sigma2= 0.84
# rho= 0.56 	mu1= -0.94 	mu2= 2.27 	sigma1= 1.83 	sigma2= 0.84
# rho= 0.56 	mu1= -0.94 	mu2= 2.27 	sigma1= 1.83 	sigma2= 0.84
# rho= 0.56 	mu1= -0.94 	mu2= 2.27 	sigma1= 1.82 	sigma2= 0.84
# rho= 0.55 	mu1= -0.95 	mu2= 2.27 	sigma1= 1.82 	sigma2= 0.84
# rho= 0.55 	mu1= -0.95 	mu2= 2.27 	sigma1= 1.82 	sigma2= 0.84
# rho= 0.55 	mu1= -0.95 	mu2= 2.27 	sigma1= 1.82 	sigma2= 0.84
# rho= 0.55 	mu1= -0.96 	mu2= 2.27 	sigma1= 1.82 	sigma2= 0.84
# rho= 0.55 	mu1= -0.96 	mu2= 2.27 	sigma1= 1.81 	sigma2= 0.84
# rho= 0.55 	mu1= -0.96 	mu2= 2.27 	sigma1= 1.81 	sigma2= 0.84
# rho= 0.55 	mu1= -0.96 	mu2= 2.27 	sigma1= 1.81 	sigma2= 0.84
# rho= 0.55 	mu1= -0.97 	mu2= 2.27 	sigma1= 1.81 	sigma2= 0.84
# rho= 0.55 	mu1= -0.97 	mu2= 2.27 	sigma1= 1.81 	sigma2= 0.84
# rho= 0.55 	mu1= -0.97 	mu2= 2.27 	sigma1= 1.80 	sigma2= 0.84
# rho= 0.55 	mu1= -0.97 	mu2= 2.27 	sigma1= 1.80 	sigma2= 0.84
# rho= 0.55 	mu1= -0.98 	mu2= 2.27 	sigma1= 1.80 	sigma2= 0.84
# rho= 0.55 	mu1= -0.98 	mu2= 2.27 	sigma1= 1.80 	sigma2= 0.84
# rho= 0.55 	mu1= -0.98 	mu2= 2.27 	sigma1= 1.80 	sigma2= 0.84
# rho= 0.55 	mu1= -0.98 	mu2= 2.27 	sigma1= 1.80 	sigma2= 0.84
# rho= 0.55 	mu1= -0.99 	mu2= 2.27 	sigma1= 1.79 	sigma2= 0.84
# rho= 0.55 	mu1= -0.99 	mu2= 2.27 	sigma1= 1.79 	sigma2= 0.84
# rho= 0.55 	mu1= -0.99 	mu2= 2.27 	sigma1= 1.79 	sigma2= 0.84
# rho= 0.55 	mu1= -1.00 	mu2= 2.27 	sigma1= 1.79 	sigma2= 0.84
# rho= 0.55 	mu1= -1.00 	mu2= 2.27 	sigma1= 1.79 	sigma2= 0.84
# rho= 0.55 	mu1= -1.00 	mu2= 2.27 	sigma1= 1.78 	sigma2= 0.84
# rho= 0.54 	mu1= -1.00 	mu2= 2.27 	sigma1= 1.78 	sigma2= 0.84
# rho= 0.54 	mu1= -1.01 	mu2= 2.27 	sigma1= 1.78 	sigma2= 0.84
# rho= 0.54 	mu1= -1.01 	mu2= 2.27 	sigma1= 1.78 	sigma2= 0.85
# rho= 0.54 	mu1= -1.01 	mu2= 2.26 	sigma1= 1.78 	sigma2= 0.85
# rho= 0.54 	mu1= -1.01 	mu2= 2.26 	sigma1= 1.77 	sigma2= 0.85
# rho= 0.54 	mu1= -1.02 	mu2= 2.26 	sigma1= 1.77 	sigma2= 0.85
# rho= 0.54 	mu1= -1.02 	mu2= 2.26 	sigma1= 1.77 	sigma2= 0.85
# rho= 0.54 	mu1= -1.02 	mu2= 2.26 	sigma1= 1.77 	sigma2= 0.85
# rho= 0.54 	mu1= -1.03 	mu2= 2.26 	sigma1= 1.77 	sigma2= 0.85
# rho= 0.54 	mu1= -1.03 	mu2= 2.26 	sigma1= 1.76 	sigma2= 0.85
# rho= 0.54 	mu1= -1.03 	mu2= 2.26 	sigma1= 1.76 	sigma2= 0.85
# rho= 0.54 	mu1= -1.03 	mu2= 2.26 	sigma1= 1.76 	sigma2= 0.85
# rho= 0.54 	mu1= -1.04 	mu2= 2.26 	sigma1= 1.76 	sigma2= 0.85
# rho= 0.54 	mu1= -1.04 	mu2= 2.26 	sigma1= 1.75 	sigma2= 0.85
# rho= 0.54 	mu1= -1.04 	mu2= 2.26 	sigma1= 1.75 	sigma2= 0.85
# rho= 0.54 	mu1= -1.04 	mu2= 2.26 	sigma1= 1.75 	sigma2= 0.85
# rho= 0.54 	mu1= -1.05 	mu2= 2.26 	sigma1= 1.75 	sigma2= 0.85
# rho= 0.54 	mu1= -1.05 	mu2= 2.26 	sigma1= 1.75 	sigma2= 0.85
# rho= 0.54 	mu1= -1.05 	mu2= 2.26 	sigma1= 1.74 	sigma2= 0.85
# rho= 0.54 	mu1= -1.06 	mu2= 2.26 	sigma1= 1.74 	sigma2= 0.85
# rho= 0.53 	mu1= -1.06 	mu2= 2.26 	sigma1= 1.74 	sigma2= 0.85
# rho= 0.53 	mu1= -1.06 	mu2= 2.26 	sigma1= 1.74 	sigma2= 0.85
# rho= 0.53 	mu1= -1.06 	mu2= 2.26 	sigma1= 1.74 	sigma2= 0.85
# rho= 0.53 	mu1= -1.07 	mu2= 2.26 	sigma1= 1.73 	sigma2= 0.85
# rho= 0.53 	mu1= -1.07 	mu2= 2.26 	sigma1= 1.73 	sigma2= 0.85
# rho= 0.53 	mu1= -1.07 	mu2= 2.26 	sigma1= 1.73 	sigma2= 0.85
# rho= 0.53 	mu1= -1.08 	mu2= 2.26 	sigma1= 1.73 	sigma2= 0.85
# rho= 0.53 	mu1= -1.08 	mu2= 2.26 	sigma1= 1.73 	sigma2= 0.85
# rho= 0.53 	mu1= -1.08 	mu2= 2.26 	sigma1= 1.72 	sigma2= 0.85
# rho= 0.53 	mu1= -1.08 	mu2= 2.26 	sigma1= 1.72 	sigma2= 0.85
# rho= 0.53 	mu1= -1.09 	mu2= 2.26 	sigma1= 1.72 	sigma2= 0.85
# rho= 0.53 	mu1= -1.09 	mu2= 2.26 	sigma1= 1.72 	sigma2= 0.86
# rho= 0.53 	mu1= -1.09 	mu2= 2.26 	sigma1= 1.71 	sigma2= 0.86
# rho= 0.53 	mu1= -1.10 	mu2= 2.25 	sigma1= 1.71 	sigma2= 0.86
# rho= 0.53 	mu1= -1.10 	mu2= 2.25 	sigma1= 1.71 	sigma2= 0.86
# rho= 0.53 	mu1= -1.10 	mu2= 2.25 	sigma1= 1.71 	sigma2= 0.86
# rho= 0.53 	mu1= -1.10 	mu2= 2.25 	sigma1= 1.71 	sigma2= 0.86
# rho= 0.53 	mu1= -1.11 	mu2= 2.25 	sigma1= 1.70 	sigma2= 0.86
# rho= 0.53 	mu1= -1.11 	mu2= 2.25 	sigma1= 1.70 	sigma2= 0.86
# rho= 0.53 	mu1= -1.11 	mu2= 2.25 	sigma1= 1.70 	sigma2= 0.86
# rho= 0.52 	mu1= -1.12 	mu2= 2.25 	sigma1= 1.70 	sigma2= 0.86
# rho= 0.52 	mu1= -1.12 	mu2= 2.25 	sigma1= 1.69 	sigma2= 0.86
# rho= 0.52 	mu1= -1.12 	mu2= 2.25 	sigma1= 1.69 	sigma2= 0.86
# rho= 0.52 	mu1= -1.13 	mu2= 2.25 	sigma1= 1.69 	sigma2= 0.86
# rho= 0.52 	mu1= -1.13 	mu2= 2.25 	sigma1= 1.69 	sigma2= 0.86
# rho= 0.52 	mu1= -1.13 	mu2= 2.25 	sigma1= 1.69 	sigma2= 0.86
# rho= 0.52 	mu1= -1.13 	mu2= 2.25 	sigma1= 1.68 	sigma2= 0.86
# rho= 0.52 	mu1= -1.14 	mu2= 2.25 	sigma1= 1.68 	sigma2= 0.86
# rho= 0.52 	mu1= -1.14 	mu2= 2.25 	sigma1= 1.68 	sigma2= 0.86
# rho= 0.52 	mu1= -1.14 	mu2= 2.25 	sigma1= 1.68 	sigma2= 0.86
# rho= 0.52 	mu1= -1.15 	mu2= 2.25 	sigma1= 1.67 	sigma2= 0.86
# rho= 0.52 	mu1= -1.15 	mu2= 2.25 	sigma1= 1.67 	sigma2= 0.86
# rho= 0.52 	mu1= -1.15 	mu2= 2.25 	sigma1= 1.67 	sigma2= 0.86
# rho= 0.52 	mu1= -1.16 	mu2= 2.25 	sigma1= 1.67 	sigma2= 0.86
# rho= 0.52 	mu1= -1.16 	mu2= 2.25 	sigma1= 1.67 	sigma2= 0.86
# rho= 0.52 	mu1= -1.16 	mu2= 2.24 	sigma1= 1.66 	sigma2= 0.86
# rho= 0.52 	mu1= -1.16 	mu2= 2.24 	sigma1= 1.66 	sigma2= 0.86
# rho= 0.52 	mu1= -1.17 	mu2= 2.24 	sigma1= 1.66 	sigma2= 0.86
# rho= 0.52 	mu1= -1.17 	mu2= 2.24 	sigma1= 1.66 	sigma2= 0.86
# rho= 0.52 	mu1= -1.17 	mu2= 2.24 	sigma1= 1.65 	sigma2= 0.86
# rho= 0.51 	mu1= -1.18 	mu2= 2.24 	sigma1= 1.65 	sigma2= 0.86
# rho= 0.51 	mu1= -1.18 	mu2= 2.24 	sigma1= 1.65 	sigma2= 0.86
# rho= 0.51 	mu1= -1.18 	mu2= 2.24 	sigma1= 1.65 	sigma2= 0.87
# rho= 0.51 	mu1= -1.19 	mu2= 2.24 	sigma1= 1.64 	sigma2= 0.87
# rho= 0.51 	mu1= -1.19 	mu2= 2.24 	sigma1= 1.64 	sigma2= 0.87
# rho= 0.51 	mu1= -1.19 	mu2= 2.24 	sigma1= 1.64 	sigma2= 0.87
# rho= 0.51 	mu1= -1.19 	mu2= 2.24 	sigma1= 1.64 	sigma2= 0.87
# rho= 0.51 	mu1= -1.20 	mu2= 2.24 	sigma1= 1.63 	sigma2= 0.87
# rho= 0.51 	mu1= -1.20 	mu2= 2.24 	sigma1= 1.63 	sigma2= 0.87
# rho= 0.51 	mu1= -1.20 	mu2= 2.24 	sigma1= 1.63 	sigma2= 0.87
# rho= 0.51 	mu1= -1.21 	mu2= 2.24 	sigma1= 1.63 	sigma2= 0.87
# rho= 0.51 	mu1= -1.21 	mu2= 2.24 	sigma1= 1.62 	sigma2= 0.87
# rho= 0.51 	mu1= -1.21 	mu2= 2.24 	sigma1= 1.62 	sigma2= 0.87
# rho= 0.51 	mu1= -1.22 	mu2= 2.24 	sigma1= 1.62 	sigma2= 0.87
# rho= 0.51 	mu1= -1.22 	mu2= 2.23 	sigma1= 1.62 	sigma2= 0.87
# rho= 0.51 	mu1= -1.22 	mu2= 2.23 	sigma1= 1.62 	sigma2= 0.87
# rho= 0.51 	mu1= -1.23 	mu2= 2.23 	sigma1= 1.61 	sigma2= 0.87
# rho= 0.51 	mu1= -1.23 	mu2= 2.23 	sigma1= 1.61 	sigma2= 0.87
# rho= 0.51 	mu1= -1.23 	mu2= 2.23 	sigma1= 1.61 	sigma2= 0.87
# rho= 0.50 	mu1= -1.24 	mu2= 2.23 	sigma1= 1.61 	sigma2= 0.87
# rho= 0.50 	mu1= -1.24 	mu2= 2.23 	sigma1= 1.60 	sigma2= 0.87
# rho= 0.50 	mu1= -1.24 	mu2= 2.23 	sigma1= 1.60 	sigma2= 0.87
# rho= 0.50 	mu1= -1.24 	mu2= 2.23 	sigma1= 1.60 	sigma2= 0.87
# rho= 0.50 	mu1= -1.25 	mu2= 2.23 	sigma1= 1.60 	sigma2= 0.87
# rho= 0.50 	mu1= -1.25 	mu2= 2.23 	sigma1= 1.59 	sigma2= 0.87
# rho= 0.50 	mu1= -1.25 	mu2= 2.23 	sigma1= 1.59 	sigma2= 0.87
# rho= 0.50 	mu1= -1.26 	mu2= 2.23 	sigma1= 1.59 	sigma2= 0.87
# rho= 0.50 	mu1= -1.26 	mu2= 2.23 	sigma1= 1.59 	sigma2= 0.87
# rho= 0.50 	mu1= -1.26 	mu2= 2.23 	sigma1= 1.58 	sigma2= 0.87
# rho= 0.50 	mu1= -1.27 	mu2= 2.23 	sigma1= 1.58 	sigma2= 0.87
# rho= 0.50 	mu1= -1.27 	mu2= 2.22 	sigma1= 1.58 	sigma2= 0.87
# rho= 0.50 	mu1= -1.27 	mu2= 2.22 	sigma1= 1.58 	sigma2= 0.87
# rho= 0.50 	mu1= -1.28 	mu2= 2.22 	sigma1= 1.57 	sigma2= 0.87
# rho= 0.50 	mu1= -1.28 	mu2= 2.22 	sigma1= 1.57 	sigma2= 0.87
# rho= 0.50 	mu1= -1.28 	mu2= 2.22 	sigma1= 1.57 	sigma2= 0.88
# rho= 0.50 	mu1= -1.29 	mu2= 2.22 	sigma1= 1.57 	sigma2= 0.88
# rho= 0.50 	mu1= -1.29 	mu2= 2.22 	sigma1= 1.56 	sigma2= 0.88
# rho= 0.50 	mu1= -1.29 	mu2= 2.22 	sigma1= 1.56 	sigma2= 0.88
# rho= 0.49 	mu1= -1.30 	mu2= 2.22 	sigma1= 1.56 	sigma2= 0.88
# rho= 0.49 	mu1= -1.30 	mu2= 2.22 	sigma1= 1.55 	sigma2= 0.88
# rho= 0.49 	mu1= -1.30 	mu2= 2.22 	sigma1= 1.55 	sigma2= 0.88
# rho= 0.49 	mu1= -1.31 	mu2= 2.22 	sigma1= 1.55 	sigma2= 0.88
# rho= 0.49 	mu1= -1.31 	mu2= 2.22 	sigma1= 1.55 	sigma2= 0.88
# rho= 0.49 	mu1= -1.31 	mu2= 2.22 	sigma1= 1.54 	sigma2= 0.88
# rho= 0.49 	mu1= -1.32 	mu2= 2.22 	sigma1= 1.54 	sigma2= 0.88
# rho= 0.49 	mu1= -1.32 	mu2= 2.21 	sigma1= 1.54 	sigma2= 0.88
# rho= 0.49 	mu1= -1.32 	mu2= 2.21 	sigma1= 1.54 	sigma2= 0.88
# rho= 0.49 	mu1= -1.33 	mu2= 2.21 	sigma1= 1.53 	sigma2= 0.88
# rho= 0.49 	mu1= -1.33 	mu2= 2.21 	sigma1= 1.53 	sigma2= 0.88
# rho= 0.49 	mu1= -1.33 	mu2= 2.21 	sigma1= 1.53 	sigma2= 0.88
# rho= 0.49 	mu1= -1.34 	mu2= 2.21 	sigma1= 1.53 	sigma2= 0.88
# rho= 0.49 	mu1= -1.34 	mu2= 2.21 	sigma1= 1.52 	sigma2= 0.88
# rho= 0.49 	mu1= -1.34 	mu2= 2.21 	sigma1= 1.52 	sigma2= 0.88
# rho= 0.49 	mu1= -1.34 	mu2= 2.21 	sigma1= 1.52 	sigma2= 0.88
# rho= 0.49 	mu1= -1.35 	mu2= 2.21 	sigma1= 1.52 	sigma2= 0.88
# rho= 0.49 	mu1= -1.35 	mu2= 2.21 	sigma1= 1.51 	sigma2= 0.88
# rho= 0.49 	mu1= -1.35 	mu2= 2.21 	sigma1= 1.51 	sigma2= 0.88
# rho= 0.48 	mu1= -1.36 	mu2= 2.21 	sigma1= 1.51 	sigma2= 0.88
# rho= 0.48 	mu1= -1.36 	mu2= 2.21 	sigma1= 1.50 	sigma2= 0.88
# rho= 0.48 	mu1= -1.36 	mu2= 2.20 	sigma1= 1.50 	sigma2= 0.88
# rho= 0.48 	mu1= -1.37 	mu2= 2.20 	sigma1= 1.50 	sigma2= 0.88
# rho= 0.48 	mu1= -1.37 	mu2= 2.20 	sigma1= 1.50 	sigma2= 0.88
# rho= 0.48 	mu1= -1.37 	mu2= 2.20 	sigma1= 1.49 	sigma2= 0.88
# rho= 0.48 	mu1= -1.38 	mu2= 2.20 	sigma1= 1.49 	sigma2= 0.88
# rho= 0.48 	mu1= -1.38 	mu2= 2.20 	sigma1= 1.49 	sigma2= 0.88
# rho= 0.48 	mu1= -1.38 	mu2= 2.20 	sigma1= 1.49 	sigma2= 0.89
# rho= 0.48 	mu1= -1.39 	mu2= 2.20 	sigma1= 1.48 	sigma2= 0.89
# rho= 0.48 	mu1= -1.39 	mu2= 2.20 	sigma1= 1.48 	sigma2= 0.89
# rho= 0.48 	mu1= -1.39 	mu2= 2.20 	sigma1= 1.48 	sigma2= 0.89
# rho= 0.48 	mu1= -1.40 	mu2= 2.20 	sigma1= 1.48 	sigma2= 0.89
# rho= 0.48 	mu1= -1.40 	mu2= 2.20 	sigma1= 1.47 	sigma2= 0.89
# rho= 0.48 	mu1= -1.40 	mu2= 2.19 	sigma1= 1.47 	sigma2= 0.89
# rho= 0.48 	mu1= -1.41 	mu2= 2.19 	sigma1= 1.47 	sigma2= 0.89
# rho= 0.48 	mu1= -1.41 	mu2= 2.19 	sigma1= 1.46 	sigma2= 0.89
# rho= 0.48 	mu1= -1.42 	mu2= 2.19 	sigma1= 1.46 	sigma2= 0.89
# rho= 0.48 	mu1= -1.42 	mu2= 2.19 	sigma1= 1.46 	sigma2= 0.89
# rho= 0.48 	mu1= -1.42 	mu2= 2.19 	sigma1= 1.46 	sigma2= 0.89
# rho= 0.47 	mu1= -1.43 	mu2= 2.19 	sigma1= 1.45 	sigma2= 0.89
# rho= 0.47 	mu1= -1.43 	mu2= 2.19 	sigma1= 1.45 	sigma2= 0.89
# rho= 0.47 	mu1= -1.43 	mu2= 2.19 	sigma1= 1.45 	sigma2= 0.89
# rho= 0.47 	mu1= -1.44 	mu2= 2.19 	sigma1= 1.44 	sigma2= 0.89
# rho= 0.47 	mu1= -1.44 	mu2= 2.19 	sigma1= 1.44 	sigma2= 0.89
# rho= 0.47 	mu1= -1.44 	mu2= 2.19 	sigma1= 1.44 	sigma2= 0.89
# rho= 0.47 	mu1= -1.45 	mu2= 2.18 	sigma1= 1.44 	sigma2= 0.89
# rho= 0.47 	mu1= -1.45 	mu2= 2.18 	sigma1= 1.43 	sigma2= 0.89
# rho= 0.47 	mu1= -1.45 	mu2= 2.18 	sigma1= 1.43 	sigma2= 0.89
# rho= 0.47 	mu1= -1.46 	mu2= 2.18 	sigma1= 1.43 	sigma2= 0.89
# rho= 0.47 	mu1= -1.46 	mu2= 2.18 	sigma1= 1.43 	sigma2= 0.89
# rho= 0.47 	mu1= -1.46 	mu2= 2.18 	sigma1= 1.42 	sigma2= 0.89
# rho= 0.47 	mu1= -1.47 	mu2= 2.18 	sigma1= 1.42 	sigma2= 0.89
# rho= 0.47 	mu1= -1.47 	mu2= 2.18 	sigma1= 1.42 	sigma2= 0.89
# rho= 0.47 	mu1= -1.47 	mu2= 2.18 	sigma1= 1.41 	sigma2= 0.89
# rho= 0.47 	mu1= -1.48 	mu2= 2.18 	sigma1= 1.41 	sigma2= 0.89
# rho= 0.47 	mu1= -1.48 	mu2= 2.18 	sigma1= 1.41 	sigma2= 0.90
# rho= 0.47 	mu1= -1.48 	mu2= 2.18 	sigma1= 1.41 	sigma2= 0.90
# rho= 0.47 	mu1= -1.49 	mu2= 2.17 	sigma1= 1.40 	sigma2= 0.90
# rho= 0.46 	mu1= -1.49 	mu2= 2.17 	sigma1= 1.40 	sigma2= 0.90
# rho= 0.46 	mu1= -1.49 	mu2= 2.17 	sigma1= 1.40 	sigma2= 0.90
# rho= 0.46 	mu1= -1.50 	mu2= 2.17 	sigma1= 1.39 	sigma2= 0.90
# rho= 0.46 	mu1= -1.50 	mu2= 2.17 	sigma1= 1.39 	sigma2= 0.90
# rho= 0.46 	mu1= -1.50 	mu2= 2.17 	sigma1= 1.39 	sigma2= 0.90
# rho= 0.46 	mu1= -1.51 	mu2= 2.17 	sigma1= 1.39 	sigma2= 0.90
# rho= 0.46 	mu1= -1.51 	mu2= 2.17 	sigma1= 1.38 	sigma2= 0.90
# rho= 0.46 	mu1= -1.51 	mu2= 2.17 	sigma1= 1.38 	sigma2= 0.90
# rho= 0.46 	mu1= -1.52 	mu2= 2.17 	sigma1= 1.38 	sigma2= 0.90
# rho= 0.46 	mu1= -1.52 	mu2= 2.17 	sigma1= 1.37 	sigma2= 0.90
# rho= 0.46 	mu1= -1.52 	mu2= 2.16 	sigma1= 1.37 	sigma2= 0.90
# rho= 0.46 	mu1= -1.53 	mu2= 2.16 	sigma1= 1.37 	sigma2= 0.90
# rho= 0.46 	mu1= -1.53 	mu2= 2.16 	sigma1= 1.37 	sigma2= 0.90
# rho= 0.46 	mu1= -1.53 	mu2= 2.16 	sigma1= 1.36 	sigma2= 0.90
# rho= 0.46 	mu1= -1.54 	mu2= 2.16 	sigma1= 1.36 	sigma2= 0.90
# rho= 0.46 	mu1= -1.54 	mu2= 2.16 	sigma1= 1.36 	sigma2= 0.90
# rho= 0.46 	mu1= -1.54 	mu2= 2.16 	sigma1= 1.36 	sigma2= 0.90
# rho= 0.46 	mu1= -1.55 	mu2= 2.16 	sigma1= 1.35 	sigma2= 0.90
# rho= 0.46 	mu1= -1.55 	mu2= 2.16 	sigma1= 1.35 	sigma2= 0.90
# rho= 0.46 	mu1= -1.55 	mu2= 2.16 	sigma1= 1.35 	sigma2= 0.90
# rho= 0.46 	mu1= -1.56 	mu2= 2.15 	sigma1= 1.34 	sigma2= 0.90
# rho= 0.45 	mu1= -1.56 	mu2= 2.15 	sigma1= 1.34 	sigma2= 0.91
# rho= 0.45 	mu1= -1.56 	mu2= 2.15 	sigma1= 1.34 	sigma2= 0.91
# rho= 0.45 	mu1= -1.57 	mu2= 2.15 	sigma1= 1.34 	sigma2= 0.91
# rho= 0.45 	mu1= -1.57 	mu2= 2.15 	sigma1= 1.33 	sigma2= 0.91
# rho= 0.45 	mu1= -1.57 	mu2= 2.15 	sigma1= 1.33 	sigma2= 0.91
# rho= 0.45 	mu1= -1.58 	mu2= 2.15 	sigma1= 1.33 	sigma2= 0.91
# rho= 0.45 	mu1= -1.58 	mu2= 2.15 	sigma1= 1.32 	sigma2= 0.91
# rho= 0.45 	mu1= -1.58 	mu2= 2.15 	sigma1= 1.32 	sigma2= 0.91
# rho= 0.45 	mu1= -1.59 	mu2= 2.15 	sigma1= 1.32 	sigma2= 0.91
# rho= 0.45 	mu1= -1.59 	mu2= 2.15 	sigma1= 1.32 	sigma2= 0.91
# rho= 0.45 	mu1= -1.59 	mu2= 2.14 	sigma1= 1.31 	sigma2= 0.91
# rho= 0.45 	mu1= -1.60 	mu2= 2.14 	sigma1= 1.31 	sigma2= 0.91
# rho= 0.45 	mu1= -1.60 	mu2= 2.14 	sigma1= 1.31 	sigma2= 0.91
# rho= 0.45 	mu1= -1.60 	mu2= 2.14 	sigma1= 1.30 	sigma2= 0.91
# rho= 0.45 	mu1= -1.61 	mu2= 2.14 	sigma1= 1.30 	sigma2= 0.91
# rho= 0.45 	mu1= -1.61 	mu2= 2.14 	sigma1= 1.30 	sigma2= 0.91
# rho= 0.45 	mu1= -1.61 	mu2= 2.14 	sigma1= 1.30 	sigma2= 0.91
# rho= 0.45 	mu1= -1.62 	mu2= 2.14 	sigma1= 1.29 	sigma2= 0.91
# rho= 0.45 	mu1= -1.62 	mu2= 2.14 	sigma1= 1.29 	sigma2= 0.91
# rho= 0.45 	mu1= -1.62 	mu2= 2.14 	sigma1= 1.29 	sigma2= 0.91
# rho= 0.45 	mu1= -1.63 	mu2= 2.13 	sigma1= 1.29 	sigma2= 0.91
# rho= 0.44 	mu1= -1.63 	mu2= 2.13 	sigma1= 1.28 	sigma2= 0.92
# rho= 0.44 	mu1= -1.63 	mu2= 2.13 	sigma1= 1.28 	sigma2= 0.92
# rho= 0.44 	mu1= -1.64 	mu2= 2.13 	sigma1= 1.28 	sigma2= 0.92
# rho= 0.44 	mu1= -1.64 	mu2= 2.13 	sigma1= 1.27 	sigma2= 0.92
# rho= 0.44 	mu1= -1.64 	mu2= 2.13 	sigma1= 1.27 	sigma2= 0.92
# rho= 0.44 	mu1= -1.65 	mu2= 2.13 	sigma1= 1.27 	sigma2= 0.92
# rho= 0.44 	mu1= -1.65 	mu2= 2.13 	sigma1= 1.27 	sigma2= 0.92
# rho= 0.44 	mu1= -1.65 	mu2= 2.13 	sigma1= 1.26 	sigma2= 0.92
# rho= 0.44 	mu1= -1.66 	mu2= 2.13 	sigma1= 1.26 	sigma2= 0.92
# rho= 0.44 	mu1= -1.66 	mu2= 2.12 	sigma1= 1.26 	sigma2= 0.92
# rho= 0.44 	mu1= -1.66 	mu2= 2.12 	sigma1= 1.26 	sigma2= 0.92
# rho= 0.44 	mu1= -1.67 	mu2= 2.12 	sigma1= 1.25 	sigma2= 0.92
# rho= 0.44 	mu1= -1.67 	mu2= 2.12 	sigma1= 1.25 	sigma2= 0.92
# rho= 0.44 	mu1= -1.67 	mu2= 2.12 	sigma1= 1.25 	sigma2= 0.92
# rho= 0.44 	mu1= -1.68 	mu2= 2.12 	sigma1= 1.24 	sigma2= 0.92
# rho= 0.44 	mu1= -1.68 	mu2= 2.12 	sigma1= 1.24 	sigma2= 0.92
# rho= 0.44 	mu1= -1.68 	mu2= 2.12 	sigma1= 1.24 	sigma2= 0.92
# rho= 0.44 	mu1= -1.69 	mu2= 2.12 	sigma1= 1.24 	sigma2= 0.92
# rho= 0.44 	mu1= -1.69 	mu2= 2.12 	sigma1= 1.23 	sigma2= 0.92
# rho= 0.44 	mu1= -1.69 	mu2= 2.12 	sigma1= 1.23 	sigma2= 0.92
# rho= 0.44 	mu1= -1.69 	mu2= 2.11 	sigma1= 1.23 	sigma2= 0.93
# rho= 0.44 	mu1= -1.70 	mu2= 2.11 	sigma1= 1.23 	sigma2= 0.93
# rho= 0.44 	mu1= -1.70 	mu2= 2.11 	sigma1= 1.22 	sigma2= 0.93
# rho= 0.44 	mu1= -1.70 	mu2= 2.11 	sigma1= 1.22 	sigma2= 0.93
# rho= 0.43 	mu1= -1.71 	mu2= 2.11 	sigma1= 1.22 	sigma2= 0.93
# rho= 0.43 	mu1= -1.71 	mu2= 2.11 	sigma1= 1.22 	sigma2= 0.93
# rho= 0.43 	mu1= -1.71 	mu2= 2.11 	sigma1= 1.21 	sigma2= 0.93
# rho= 0.43 	mu1= -1.72 	mu2= 2.11 	sigma1= 1.21 	sigma2= 0.93
# rho= 0.43 	mu1= -1.72 	mu2= 2.11 	sigma1= 1.21 	sigma2= 0.93
# rho= 0.43 	mu1= -1.72 	mu2= 2.11 	sigma1= 1.21 	sigma2= 0.93
# rho= 0.43 	mu1= -1.73 	mu2= 2.10 	sigma1= 1.20 	sigma2= 0.93
# rho= 0.43 	mu1= -1.73 	mu2= 2.10 	sigma1= 1.20 	sigma2= 0.93
# rho= 0.43 	mu1= -1.73 	mu2= 2.10 	sigma1= 1.20 	sigma2= 0.93
# rho= 0.43 	mu1= -1.73 	mu2= 2.10 	sigma1= 1.20 	sigma2= 0.93
# rho= 0.43 	mu1= -1.74 	mu2= 2.10 	sigma1= 1.19 	sigma2= 0.93
# rho= 0.43 	mu1= -1.74 	mu2= 2.10 	sigma1= 1.19 	sigma2= 0.93
# rho= 0.43 	mu1= -1.74 	mu2= 2.10 	sigma1= 1.19 	sigma2= 0.93
# rho= 0.43 	mu1= -1.75 	mu2= 2.10 	sigma1= 1.19 	sigma2= 0.93
# rho= 0.43 	mu1= -1.75 	mu2= 2.10 	sigma1= 1.18 	sigma2= 0.93
# rho= 0.43 	mu1= -1.75 	mu2= 2.10 	sigma1= 1.18 	sigma2= 0.94
# rho= 0.43 	mu1= -1.75 	mu2= 2.10 	sigma1= 1.18 	sigma2= 0.94
# rho= 0.43 	mu1= -1.76 	mu2= 2.09 	sigma1= 1.18 	sigma2= 0.94
# rho= 0.43 	mu1= -1.76 	mu2= 2.09 	sigma1= 1.18 	sigma2= 0.94
# rho= 0.43 	mu1= -1.76 	mu2= 2.09 	sigma1= 1.17 	sigma2= 0.94
# rho= 0.43 	mu1= -1.77 	mu2= 2.09 	sigma1= 1.17 	sigma2= 0.94
# rho= 0.43 	mu1= -1.77 	mu2= 2.09 	sigma1= 1.17 	sigma2= 0.94
# rho= 0.43 	mu1= -1.77 	mu2= 2.09 	sigma1= 1.17 	sigma2= 0.94
# rho= 0.43 	mu1= -1.77 	mu2= 2.09 	sigma1= 1.16 	sigma2= 0.94
# rho= 0.43 	mu1= -1.78 	mu2= 2.09 	sigma1= 1.16 	sigma2= 0.94
# rho= 0.43 	mu1= -1.78 	mu2= 2.09 	sigma1= 1.16 	sigma2= 0.94
# rho= 0.43 	mu1= -1.78 	mu2= 2.09 	sigma1= 1.16 	sigma2= 0.94
# rho= 0.42 	mu1= -1.78 	mu2= 2.09 	sigma1= 1.16 	sigma2= 0.94
# rho= 0.42 	mu1= -1.79 	mu2= 2.08 	sigma1= 1.15 	sigma2= 0.94
# rho= 0.42 	mu1= -1.79 	mu2= 2.08 	sigma1= 1.15 	sigma2= 0.94
# rho= 0.42 	mu1= -1.79 	mu2= 2.08 	sigma1= 1.15 	sigma2= 0.94
# rho= 0.42 	mu1= -1.79 	mu2= 2.08 	sigma1= 1.15 	sigma2= 0.94
# rho= 0.42 	mu1= -1.80 	mu2= 2.08 	sigma1= 1.14 	sigma2= 0.94
# rho= 0.42 	mu1= -1.80 	mu2= 2.08 	sigma1= 1.14 	sigma2= 0.95
# rho= 0.42 	mu1= -1.80 	mu2= 2.08 	sigma1= 1.14 	sigma2= 0.95
# rho= 0.42 	mu1= -1.80 	mu2= 2.08 	sigma1= 1.14 	sigma2= 0.95
# rho= 0.42 	mu1= -1.81 	mu2= 2.08 	sigma1= 1.14 	sigma2= 0.95
# rho= 0.42 	mu1= -1.81 	mu2= 2.08 	sigma1= 1.13 	sigma2= 0.95
# rho= 0.42 	mu1= -1.81 	mu2= 2.08 	sigma1= 1.13 	sigma2= 0.95
# rho= 0.42 	mu1= -1.81 	mu2= 2.07 	sigma1= 1.13 	sigma2= 0.95
# rho= 0.42 	mu1= -1.82 	mu2= 2.07 	sigma1= 1.13 	sigma2= 0.95
# rho= 0.42 	mu1= -1.82 	mu2= 2.07 	sigma1= 1.13 	sigma2= 0.95
# rho= 0.42 	mu1= -1.82 	mu2= 2.07 	sigma1= 1.12 	sigma2= 0.95
# rho= 0.42 	mu1= -1.82 	mu2= 2.07 	sigma1= 1.12 	sigma2= 0.95
# rho= 0.42 	mu1= -1.83 	mu2= 2.07 	sigma1= 1.12 	sigma2= 0.95
# rho= 0.42 	mu1= -1.83 	mu2= 2.07 	sigma1= 1.12 	sigma2= 0.95
# rho= 0.42 	mu1= -1.83 	mu2= 2.07 	sigma1= 1.12 	sigma2= 0.95
# rho= 0.42 	mu1= -1.83 	mu2= 2.07 	sigma1= 1.12 	sigma2= 0.95
# rho= 0.42 	mu1= -1.84 	mu2= 2.07 	sigma1= 1.11 	sigma2= 0.95
# rho= 0.42 	mu1= -1.84 	mu2= 2.07 	sigma1= 1.11 	sigma2= 0.95
# rho= 0.42 	mu1= -1.84 	mu2= 2.07 	sigma1= 1.11 	sigma2= 0.95
# rho= 0.42 	mu1= -1.84 	mu2= 2.06 	sigma1= 1.11 	sigma2= 0.95
# rho= 0.42 	mu1= -1.84 	mu2= 2.06 	sigma1= 1.11 	sigma2= 0.95
# rho= 0.42 	mu1= -1.85 	mu2= 2.06 	sigma1= 1.11 	sigma2= 0.96
# rho= 0.42 	mu1= -1.85 	mu2= 2.06 	sigma1= 1.10 	sigma2= 0.96
# rho= 0.42 	mu1= -1.85 	mu2= 2.06 	sigma1= 1.10 	sigma2= 0.96
# rho= 0.42 	mu1= -1.85 	mu2= 2.06 	sigma1= 1.10 	sigma2= 0.96
# rho= 0.42 	mu1= -1.86 	mu2= 2.06 	sigma1= 1.10 	sigma2= 0.96
# rho= 0.42 	mu1= -1.86 	mu2= 2.06 	sigma1= 1.10 	sigma2= 0.96
# rho= 0.42 	mu1= -1.86 	mu2= 2.06 	sigma1= 1.10 	sigma2= 0.96
# rho= 0.42 	mu1= -1.86 	mu2= 2.06 	sigma1= 1.09 	sigma2= 0.96
# rho= 0.42 	mu1= -1.86 	mu2= 2.06 	sigma1= 1.09 	sigma2= 0.96
# rho= 0.42 	mu1= -1.87 	mu2= 2.06 	sigma1= 1.09 	sigma2= 0.96
# rho= 0.41 	mu1= -1.87 	mu2= 2.06 	sigma1= 1.09 	sigma2= 0.96
# rho= 0.41 	mu1= -1.87 	mu2= 2.06 	sigma1= 1.09 	sigma2= 0.96
# rho= 0.41 	mu1= -1.87 	mu2= 2.05 	sigma1= 1.09 	sigma2= 0.96
# rho= 0.41 	mu1= -1.87 	mu2= 2.05 	sigma1= 1.09 	sigma2= 0.96
# rho= 0.41 	mu1= -1.87 	mu2= 2.05 	sigma1= 1.08 	sigma2= 0.96
# rho= 0.41 	mu1= -1.88 	mu2= 2.05 	sigma1= 1.08 	sigma2= 0.96
# rho= 0.41 	mu1= -1.88 	mu2= 2.05 	sigma1= 1.08 	sigma2= 0.96
# rho= 0.41 	mu1= -1.88 	mu2= 2.05 	sigma1= 1.08 	sigma2= 0.96
# rho= 0.41 	mu1= -1.88 	mu2= 2.05 	sigma1= 1.08 	sigma2= 0.96
# rho= 0.41 	mu1= -1.88 	mu2= 2.05 	sigma1= 1.08 	sigma2= 0.96
# rho= 0.41 	mu1= -1.89 	mu2= 2.05 	sigma1= 1.08 	sigma2= 0.96
# rho= 0.41 	mu1= -1.89 	mu2= 2.05 	sigma1= 1.07 	sigma2= 0.97
# rho= 0.41 	mu1= -1.89 	mu2= 2.05 	sigma1= 1.07 	sigma2= 0.97
# rho= 0.41 	mu1= -1.89 	mu2= 2.05 	sigma1= 1.07 	sigma2= 0.97
# rho= 0.41 	mu1= -1.89 	mu2= 2.05 	sigma1= 1.07 	sigma2= 0.97
# rho= 0.41 	mu1= -1.89 	mu2= 2.05 	sigma1= 1.07 	sigma2= 0.97
# rho= 0.41 	mu1= -1.90 	mu2= 2.05 	sigma1= 1.07 	sigma2= 0.97
# rho= 0.41 	mu1= -1.90 	mu2= 2.04 	sigma1= 1.07 	sigma2= 0.97
# rho= 0.41 	mu1= -1.90 	mu2= 2.04 	sigma1= 1.07 	sigma2= 0.97
# rho= 0.41 	mu1= -1.90 	mu2= 2.04 	sigma1= 1.07 	sigma2= 0.97
# rho= 0.41 	mu1= -1.90 	mu2= 2.04 	sigma1= 1.06 	sigma2= 0.97
# rho= 0.41 	mu1= -1.90 	mu2= 2.04 	sigma1= 1.06 	sigma2= 0.97
# rho= 0.41 	mu1= -1.90 	mu2= 2.04 	sigma1= 1.06 	sigma2= 0.97
# rho= 0.41 	mu1= -1.91 	mu2= 2.04 	sigma1= 1.06 	sigma2= 0.97
# rho= 0.41 	mu1= -1.91 	mu2= 2.04 	sigma1= 1.06 	sigma2= 0.97
# rho= 0.41 	mu1= -1.91 	mu2= 2.04 	sigma1= 1.06 	sigma2= 0.97
# rho= 0.41 	mu1= -1.91 	mu2= 2.04 	sigma1= 1.06 	sigma2= 0.97
# rho= 0.41 	mu1= -1.91 	mu2= 2.04 	sigma1= 1.06 	sigma2= 0.97
# rho= 0.41 	mu1= -1.91 	mu2= 2.04 	sigma1= 1.06 	sigma2= 0.97
# rho= 0.41 	mu1= -1.91 	mu2= 2.04 	sigma1= 1.05 	sigma2= 0.97
# rho= 0.41 	mu1= -1.92 	mu2= 2.04 	sigma1= 1.05 	sigma2= 0.97
# rho= 0.41 	mu1= -1.92 	mu2= 2.04 	sigma1= 1.05 	sigma2= 0.97
# rho= 0.41 	mu1= -1.92 	mu2= 2.04 	sigma1= 1.05 	sigma2= 0.97
# rho= 0.41 	mu1= -1.92 	mu2= 2.04 	sigma1= 1.05 	sigma2= 0.97
# rho= 0.41 	mu1= -1.92 	mu2= 2.03 	sigma1= 1.05 	sigma2= 0.97
# rho= 0.41 	mu1= -1.92 	mu2= 2.03 	sigma1= 1.05 	sigma2= 0.97
# rho= 0.41 	mu1= -1.92 	mu2= 2.03 	sigma1= 1.05 	sigma2= 0.97
# rho= 0.41 	mu1= -1.92 	mu2= 2.03 	sigma1= 1.05 	sigma2= 0.98
# rho= 0.41 	mu1= -1.93 	mu2= 2.03 	sigma1= 1.05 	sigma2= 0.98
# rho= 0.41 	mu1= -1.93 	mu2= 2.03 	sigma1= 1.05 	sigma2= 0.98
# rho= 0.41 	mu1= -1.93 	mu2= 2.03 	sigma1= 1.05 	sigma2= 0.98
# rho= 0.41 	mu1= -1.93 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.93 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.93 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.93 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.93 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.93 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.94 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.94 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.94 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.94 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.94 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.94 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.94 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.94 	mu2= 2.03 	sigma1= 1.04 	sigma2= 0.98
# rho= 0.41 	mu1= -1.94 	mu2= 2.03 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.41 	mu1= -1.94 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.41 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.41 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.41 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.41 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.41 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.41 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.41 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.41 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.41 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.40 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.40 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.40 	mu1= -1.95 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.03 	sigma2= 0.98
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99
# rho= 0.40 	mu1= -1.96 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99
# rho= 0.40 	mu1= -1.97 	mu2= 2.02 	sigma1= 1.02 	sigma2= 0.99

# %%
print("ML estimation of the parameters though gradient descent after 1000 iterations:")
print('rho=', "%.4f" % rho, '\tmu1=', "%.4f" % mu1, '\tmu2=', "%.4f" % mu2, \
          '\tsigma1=', "%.4f" % sigma1, '\tsigma2=', "%.4f" % sigma2)
# Out:
# ML estimation of the parameters though gradient descent after 1000 iterations:
# rho= 0.4035 	mu1= -1.9660 	mu2= 2.0155 	sigma1= 1.0199 	sigma2= 0.9876

# %% [markdown]
# ## EM algorithm estimation
